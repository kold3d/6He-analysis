# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
import rootprint
import rootnotes
import utils

# %%
ROOT.gROOT.Reset()
#Clear all stored canvases/variables

# %%
inputFile_out_dEsumTotal = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out_dEsumTotal.root")
inputFile_out_dEsum73 = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out_dEsum73.root")

inputFile_dEcuts = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/dEsumCuts.root")

# %%
# Wire 7 + 3 #
dEsum_E_7_3_1_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_1_1")
dEsum_E_7_3_1_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_1_2")
dEsum_E_7_3_1_3 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_1_3")
dEsum_E_7_3_1_4 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_1_4")

dEsum_E_7_3_2_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_2_1")
dEsum_E_7_3_2_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_2_2")
dEsum_E_7_3_2_3 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_2_3")
dEsum_E_7_3_2_4 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_2_4")

dEsum_E_7_3_3_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_3_1")
dEsum_E_7_3_3_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_3_2")
dEsum_E_7_3_3_3 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_3_3")
dEsum_E_7_3_3_4 = inputFile_out_dEsumTotal.Get("dEsum_E_7_3_3_4")

# Wire 7 + 4 #
dEsum_E_7_4_1_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_1_1")
dEsum_E_7_4_1_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_1_2")

dEsum_E_7_4_2_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_2_1")
dEsum_E_7_4_2_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_2_2")

dEsum_E_7_4_3_1 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_3_1")
dEsum_E_7_4_3_2 = inputFile_out_dEsumTotal.Get("dEsum_E_7_4_3_2")

# Wire 8 + 4 #
dEsum_E_8_4_1_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_1_1")
dEsum_E_8_4_1_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_1_2")

dEsum_E_8_4_2_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_2_1")
dEsum_E_8_4_2_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_2_2")

dEsum_E_8_4_3_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_3_1")
dEsum_E_8_4_3_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_4_3_2")

# Wire 8 + 5 #
dEsum_E_8_5_1_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_1_1")
dEsum_E_8_5_1_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_1_2")

dEsum_E_8_5_2_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_2_1")
dEsum_E_8_5_2_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_2_2")

dEsum_E_8_5_3_1 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_3_1")
dEsum_E_8_5_3_2 = inputFile_out_dEsumTotal.Get("dEsum_E_8_5_3_2")

# Total Energy Projections (quadrants for all wires) #
dEsum_e_proj_1_1 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_1_1")
dEsum_e_proj_1_2 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_1_2")
dEsum_e_proj_1_3 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_1_3")
dEsum_e_proj_1_4 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_1_4")

dEsum_e_proj_2_1 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_2_1")
dEsum_e_proj_2_2 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_2_2")
dEsum_e_proj_2_3 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_2_3")
dEsum_e_proj_2_4 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_2_4")

dEsum_e_proj_3_1 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_3_1")
dEsum_e_proj_3_2 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_3_2")
dEsum_e_proj_3_3 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_3_3")
dEsum_e_proj_3_4 = inputFile_out_dEsumTotal.Get("dEsum_e_proj_3_4")

# Energy Projections for wires 7+3 #
dEsum_e_proj_1_1_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_1_1")
dEsum_e_proj_1_2_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_1_2")

dEsum_e_proj_2_1_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_2_1")
dEsum_e_proj_2_2_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_2_2")

dEsum_e_proj_3_1_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_3_1")
dEsum_e_proj_3_2_73 = inputFile_out_dEsum73.Get("dEsum_e_proj_3_2")

# %%
cut7311 = inputFile_dEcuts.Get("cut7311")
cut7312 = inputFile_dEcuts.Get("cut7312")
cut7313 = inputFile_dEcuts.Get("cut7313")
cut7314 = inputFile_dEcuts.Get("cut7314")

cut7321 = inputFile_dEcuts.Get("cut7321")
cut7322 = inputFile_dEcuts.Get("cut7322")
cut7323 = inputFile_dEcuts.Get("cut7323")
cut7324 = inputFile_dEcuts.Get("cut7324")

cut7331 = inputFile_dEcuts.Get("cut7331")
cut7332 = inputFile_dEcuts.Get("cut7332")
cut7333 = inputFile_dEcuts.Get("cut7333")
cut7334 = inputFile_dEcuts.Get("cut7334")

cut7411 = inputFile_dEcuts.Get("cut7411")
cut7412 = inputFile_dEcuts.Get("cut7412")

cut7421 = inputFile_dEcuts.Get("cut7421")
cut7422 = inputFile_dEcuts.Get("cut7422")

cut7431 = inputFile_dEcuts.Get("cut7431")
cut7432 = inputFile_dEcuts.Get("cut7432")

cut8411 = inputFile_dEcuts.Get("cut8411")
cut8412 = inputFile_dEcuts.Get("cut8412")

cut8421 = inputFile_dEcuts.Get("cut8421")
cut8422 = inputFile_dEcuts.Get("cut8422")

cut8431 = inputFile_dEcuts.Get("cut8431")
cut8432 = inputFile_dEcuts.Get("cut8432")

cut8511 = inputFile_dEcuts.Get("cut8511")
cut8512 = inputFile_dEcuts.Get("cut8512")

cut8521 = inputFile_dEcuts.Get("cut8521")
cut8522 = inputFile_dEcuts.Get("cut8522")

cut8531 = inputFile_dEcuts.Get("cut8531")
cut8532 = inputFile_dEcuts.Get("cut8532")

# %% [markdown]
# <sup>6</sup>He(α,α) Analysis Update
# =====================
# December 7, 2016
# --------------------

# %% [markdown]
# dE-Sum (added up dE from first and second layer wires)
# ===
# * This provided fairly clean distinction between alphas and 6He
#
# * Looked all wire combinations for upper quadrants mainly.
#     * wire 7+3
#     * wire 7+4
#     * wire 8+4
#     * wire 8+5
# * Made all the cuts on these histograms (for alphas), and plotted the energy spectras for them.
#
# Fixed Cluster issues
# ---
# * Faulty and bloated code caused issues
# * Re-wrote almost all of my code, and made it more streamlined.

# %%
# %%rootprint
# det1p = rootnotes.canvas('Detector 1 inPlane', (696*2,472*2))
# det1p.Divide(2,2)
# det1p.cd(1)
# dEsum_E_7_3_1_1.SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 1")
# dEsum_E_7_3_1_1.Draw("colz")
# cut7311.Draw("same")
#
#
# det1p.cd(2)
# dEsum_E_7_3_1_2.SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 2")
# dEsum_E_7_3_1_2.Draw("colz")
# cut7312.Draw("same")
#
# det1p.cd(3)
# dEsum_E_7_3_1_3.SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 3")
# dEsum_E_7_3_1_3.Draw("colz")
# cut7313.Draw("same")
#
# det1p.cd(4)
# dEsum_E_7_3_1_4.SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 4")
# dEsum_E_7_3_1_4.Draw("colz")
# cut7314.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane

# %% [markdown]
# Detector 1
# ====

# %% [markdown]
# In plane wires (Wire 7 & Wire 3)
# ----

# %%
det1p
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane") at 0x56174fd4f010>
# Info in <TCanvas::Print>: png file /tmp/tmps1O7l8.png has been created

# %%
# %%rootprint
# det1pE = rootnotes.canvas('Detector 1 inPlane E Projection', (696*2,472*2))
# det1pE.Divide(2,2)
#
# det1pE.cd(1)
# dEsum_e_proj_1_1_73.SetTitle("Energy Spectrum Detector 1 Quad 1")
# dEsum_e_proj_1_1_73.Draw()
#
# det1pE.cd(2)
# dEsum_e_proj_1_2_73.SetTitle("Energy Spectrum Detector 1 Quad 2")
# dEsum_e_proj_1_2_73.Draw()
#
# det1pE.cd(3)
# dEsum_e_proj_1_3.SetTitle("Energy Spectrum Detector 1 Quad 3")
# dEsum_e_proj_1_3.Draw()
#
# det1pE.cd(4)
# dEsum_e_proj_1_4.SetTitle("Energy Spectrum Detector 1 Quad 4")
# dEsum_e_proj_1_4.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane E Projection

# %%
det1pE
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane E Projection") at 0x5617505cf3d0>
# Info in <TCanvas::Print>: png file /tmp/tmpjuGfDz.png has been created

# %%
# %%rootprint
# det1o = rootnotes.canvas('Detector 1 offPlane', (696*2,472*3))
# det1o.Divide(2,3)
# det1o.cd(1)
# dEsum_E_7_4_1_1.SetTitle("dE(W7+W4) vs. E, Detctor 1 Quad 1")
# dEsum_E_7_4_1_1.Draw("colz")
# cut7411.Draw("same")
#
#
# det1o.cd(2)
# dEsum_E_7_4_1_2.SetTitle("dE(W7+W4) vs. E, Detctor 1 Quad 2")
# dEsum_E_7_4_1_2.Draw("colz")
# cut7412.Draw("same")
#
# det1o.cd(3)
# dEsum_E_8_4_1_1.SetTitle("dE(W8+W4) vs. E, Detctor 1 Quad 1")
# dEsum_E_8_4_1_1.Draw("colz")
# cut8411.Draw("same")
#
# det1o.cd(4)
# dEsum_E_8_4_1_2.SetTitle("dE(W8+W4) vs. E, Detctor 1 Quad 2")
# dEsum_E_8_4_1_2.Draw("colz")
# cut8412.Draw("same")
#
# det1o.cd(5)
# dEsum_E_8_5_1_1.SetTitle("dE(W8+W5) vs. E, Detctor 1 Quad 1")
# dEsum_E_8_5_1_1.Draw("colz")
# cut8511.Draw("same")
#
# det1o.cd(6)
# dEsum_E_8_5_1_2.SetTitle("dE(W8+W5) vs. E, Detctor 1 Quad 2")
# dEsum_E_8_5_1_2.Draw("colz")
# cut8512.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 offPlane

# %% [markdown]
# Detector 1
# ====
#
# Offplane wires
# ----
# * Wires 7 & 4
# * Wires 8 & 4
# * Wires 8 & 5

# %%
det1o
# Out:
# <ROOT.TCanvas object ("Detector 1 offPlane") at 0x56174fc7b190>
# Info in <TCanvas::Print>: png file /tmp/tmpldN_1x.png has been created

# %%
# %%rootprint
# det1tE = rootnotes.canvas('Detector 1 inPlane E Projection', (696*2,472*2))
# det1tE.Divide(2,2)
#
# det1tE.cd(1)
# dEsum_e_proj_1_1.SetTitle("Energy Spectrum Detector 1 Quad 1 (Total)")
# dEsum_e_proj_1_1.Draw()
#
# det1tE.cd(2)
# dEsum_e_proj_1_2.SetTitle("Energy Spectrum Detector 1 Quad 2 (Total)")
# dEsum_e_proj_1_2.Draw()
#
# det1tE.cd(3)
# dEsum_e_proj_1_1_73.SetTitle("Energy Spectrum Detector 1 Quad 1 (W7+W3)")
# dEsum_e_proj_1_1_73.Draw()
#
# det1tE.cd(4)
# dEsum_e_proj_1_2_73.SetTitle("Energy Spectrum Detector 1 Quad 2 (W7+W3)")
# dEsum_e_proj_1_2_73.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane E Projection

# %%
det1tE
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane E Projection") at 0x56175064d5a0>
# Info in <TCanvas::Print>: png file /tmp/tmp5Y_hn4.png has been created

# %%
# %%rootprint
# det2p = rootnotes.canvas('Detector 2 inPlane', (696*2,472*2))
# det2p.Divide(2,2)
# det2p.cd(1).SetLogz()
# dEsum_E_7_3_2_1.SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 1")
# dEsum_E_7_3_2_1.Draw("colz")
# cut7321.Draw("same")
#
# det2p.cd(2).SetLogz()
# dEsum_E_7_3_2_2.SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 2")
# dEsum_E_7_3_2_2.Draw("colz")
# cut7322.Draw("same")
#
# det2p.cd(3).SetLogz()
# dEsum_E_7_3_2_3.SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 3")
# dEsum_E_7_3_2_3.Draw("colz")
# cut7323.Draw("same")
#
# det2p.cd(4).SetLogz()
# dEsum_E_7_3_2_4.SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 4")
# dEsum_E_7_3_2_4.Draw("colz")
# cut7324.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 2 inPlane

# %% [markdown]
# Detector 2
# ====

# %% [markdown]
# In plane wires (Wire 7 & Wire 3)
# ----

# %%
det2p
# Out:
# <ROOT.TCanvas object ("Detector 2 inPlane") at 0x56174fc583d0>
# Info in <TCanvas::Print>: png file /tmp/tmplC0LdY.png has been created

# %%
# %%rootprint
# det2pE = rootnotes.canvas('Detector 2 inPlane E Projection', (696*2,472*2))
# det2pE.Divide(2,2)
#
# det2pE.cd(1)
# dEsum_e_proj_2_1_73.SetTitle("Energy Spectrum Detector 2 Quad 1")
# dEsum_e_proj_2_1_73.Draw()
#
# det2pE.cd(2)
# dEsum_e_proj_2_2_73.SetTitle("Energy Spectrum Detector 2 Quad 2")
# dEsum_e_proj_2_2_73.Draw()
#
# det2pE.cd(3)
# dEsum_e_proj_2_3.SetTitle("Energy Spectrum Detector 2 Quad 3")
# dEsum_e_proj_2_3.Draw()
#
# det2pE.cd(4)
# dEsum_e_proj_2_4.SetTitle("Energy Spectrum Detector 2 Quad 4")
# dEsum_e_proj_2_4.Draw()

# %%
det2pE
# Out:
# <ROOT.TCanvas object ("Detector 2 inPlane E Projection") at 0x56174fa36ea0>
# Info in <TCanvas::Print>: png file /tmp/tmpg5vlDd.png has been created

# %%
# %%rootprint
# det2o = rootnotes.canvas('Detector 2 offPlane', (696*2,472*3))
# det2o.Divide(2,3)
# det2o.cd(1)
# dEsum_E_7_4_2_1.SetTitle("dE(W7+W4) vs. E, Detctor 2 Quad 1")
# dEsum_E_7_4_2_1.Draw("colz")
# cut7421.Draw("same")
#
# det2o.cd(2)
# dEsum_E_7_4_2_2.SetTitle("dE(W7+W4) vs. E, Detctor 2 Quad 2")
# dEsum_E_7_4_2_2.Draw("colz")
# cut7422.Draw("same")
#
# det2o.cd(3)
# dEsum_E_8_4_2_1.SetTitle("dE(W8+W4) vs. E, Detctor 2 Quad 1")
# dEsum_E_8_4_2_1.Draw("colz")
# cut8421.Draw("same")
#
# det2o.cd(4)
# dEsum_E_8_4_2_2.SetTitle("dE(W8+W4) vs. E, Detctor 2 Quad 2")
# dEsum_E_8_4_2_2.Draw("colz")
# cut8422.Draw("same")
#
# det2o.cd(5)
# dEsum_E_8_5_2_1.SetTitle("dE(W8+W5) vs. E, Detctor 2 Quad 1")
# dEsum_E_8_5_2_1.Draw("colz")
# cut8521.Draw("same")
#
# det2o.cd(6)
# dEsum_E_8_5_2_2.SetTitle("dE(W8+W5) vs. E, Detctor 2 Quad 2")
# dEsum_E_8_5_2_2.Draw("colz")
# cut8522.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 2 offPlane

# %% [markdown]
# Detector 2
# ====
#
# Offplane wires
# ----
# * Wires 7 & 4
# * Wires 8 & 4
# * Wires 8 & 5

# %%
det2o
# Out:
# <ROOT.TCanvas object ("Detector 2 offPlane") at 0x56174fc758e0>
# Info in <TCanvas::Print>: png file /tmp/tmpZtpCnY.png has been created

# %%
# %%rootprint
# det2tE = rootnotes.canvas('Detector 2 inPlane E Projection', (696*2,472*2))
# det2tE.Divide(2,2)
#
# det2tE.cd(1)
# dEsum_e_proj_2_1.SetTitle("Energy Spectrum Detector 2 Quad 1 (Total)")
# dEsum_e_proj_2_1.Draw()
#
# det2tE.cd(2)
# dEsum_e_proj_2_2.SetTitle("Energy Spectrum Detector 2 Quad 2 (Total)")
# dEsum_e_proj_2_2.Draw()
#
# det2tE.cd(3)
# dEsum_e_proj_2_1_73.SetTitle("Energy Spectrum Detector 2 Quad 1 (W7+W3)")
# dEsum_e_proj_2_1_73.Draw()
#
# det2tE.cd(4)
# dEsum_e_proj_2_2_73.SetTitle("Energy Spectrum Detector 2 Quad 2 (W7+W3)")
# dEsum_e_proj_2_2_73.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 2 inPlane E Projection

# %%
det2tE
# Out:
# <ROOT.TCanvas object ("Detector 2 inPlane E Projection") at 0x56175063c600>
# Info in <TCanvas::Print>: png file /tmp/tmpM_xsjA.png has been created

# %%
# %%rootprint
# det3p = rootnotes.canvas('Detector 3 inPlane', (696*2,472*2))
# det3p.Divide(2,2)
#
# det3p.cd(1).SetLogz()
# dEsum_E_7_3_3_1.SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 1")
# dEsum_E_7_3_3_1.Draw("colz")
# cut7331.Draw("same")
#
#
# det3p.cd(2)
# dEsum_E_7_3_3_2.SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 2")
# dEsum_E_7_3_3_2.Draw("colz")
# cut7332.Draw("same")
#
# det3p.cd(3)
# dEsum_E_7_3_3_3.SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 3")
# dEsum_E_7_3_3_3.Draw("colz")
# cut7333.Draw("same")
#
# det3p.cd(4)
# dEsum_E_7_3_3_4.SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 4")
# dEsum_E_7_3_3_4.Draw("colz")
# cut7334.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 3 inPlane

# %% [markdown]
# Detector 3
# ===

# %% [markdown]
# In plane wires
# ---

# %%
det3p
# Out:
# <ROOT.TCanvas object ("Detector 3 inPlane") at 0x56174fc67970>
# Info in <TCanvas::Print>: png file /tmp/tmpJJN40b.png has been created

# %%
# %%rootprint
# det3pE = rootnotes.canvas('Detector 3 inPlane E Projection', (696*2,472*2))
# det3pE.Divide(2,2)
#
# det3pE.cd(1)
# dEsum_e_proj_3_1_73.SetTitle("Energy Spectrum Detector 3 Quad 1")
# dEsum_e_proj_3_1_73.Draw()
#
# det3pE.cd(2)
# dEsum_e_proj_3_2_73.SetTitle("Energy Spectrum Detector 3 Quad 2")
# dEsum_e_proj_3_2_73.Draw()
#
# det3pE.cd(3)
# dEsum_e_proj_3_3.SetTitle("Energy Spectrum Detector 3 Quad 3")
# dEsum_e_proj_3_3.Draw()
#
# det3pE.cd(4)
# dEsum_e_proj_3_4.SetTitle("Energy Spectrum Detector 3 Quad 4")
# dEsum_e_proj_3_4.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 3 inPlane E Projection

# %%
det3pE
# Out:
# <ROOT.TCanvas object ("Detector 3 inPlane E Projection") at 0x5617505e8960>
# Info in <TCanvas::Print>: png file /tmp/tmpUfqGkc.png has been created

# %%
# %%rootprint
# det3o = rootnotes.canvas('Detector 3 offPlane', (696*2,472*3))
# det3o.Divide(2,3)
# det3o.cd(1)
# dEsum_E_7_4_3_1.SetTitle("dE(W7+W4) vs. E, Detctor 3 Quad 1")
# dEsum_E_7_4_3_1.Draw("colz")
# cut7431.Draw("same")
#
# det3o.cd(2)
# dEsum_E_7_4_3_2.SetTitle("dE(W7+W4) vs. E, Detctor 3 Quad 2")
# dEsum_E_7_4_3_2.Draw("colz")
# cut7432.Draw("same")
#
# det3o.cd(3)
# dEsum_E_8_4_3_1.SetTitle("dE(W8+W4) vs. E, Detctor 3 Quad 1")
# dEsum_E_8_4_3_1.Draw("colz")
# cut8431.Draw("same")
#
# det3o.cd(4)
# dEsum_E_8_4_3_2.SetTitle("dE(W8+W4) vs. E, Detctor 3 Quad 2")
# dEsum_E_8_4_3_2.Draw("colz")
# cut8432.Draw("same")
#
# det3o.cd(5)
# dEsum_E_8_5_3_1.SetTitle("dE(W8+W5) vs. E, Detctor 3 Quad 1")
# dEsum_E_8_5_3_1.Draw("colz")
# cut8531.Draw("same")
#
# det3o.cd(6)
# dEsum_E_8_5_3_2.SetTitle("dE(W8+W5) vs. E, Detctor 3 Quad 2")
# dEsum_E_8_5_3_2.Draw("colz")
# cut8532.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 3 offPlane

# %% [markdown]
# Detector 3
# ====
#
# Offplane wires
# ----
# * Wires 7 & 4
# * Wires 8 & 4
# * Wires 8 & 5

# %%
det3o
# Out:
# <ROOT.TCanvas object ("Detector 3 offPlane") at 0x56174fa3c760>
# Info in <TCanvas::Print>: png file /tmp/tmpyrDYMu.png has been created

# %%
# %%rootprint
# det3tE = rootnotes.canvas('Detector 3 inPlane E Projection', (696*2,472*2))
# det3tE.Divide(2,2)
#
# det3tE.cd(1)
# dEsum_e_proj_3_1.SetTitle("Energy Spectrum Detector 3 Quad 1 (Total)")
# dEsum_e_proj_3_1.Draw()
#
# det3tE.cd(2)
# dEsum_e_proj_3_2.SetTitle("Energy Spectrum Detector 3 Quad 2 (Total)")
# dEsum_e_proj_3_2.Draw()
#
# det3tE.cd(3)
# dEsum_e_proj_3_1_73.SetTitle("Energy Spectrum Detector 3 Quad 1 (W7+W3)")
# dEsum_e_proj_3_1_73.Draw()
#
# det3tE.cd(4)
# dEsum_e_proj_3_2_73.SetTitle("Energy Spectrum Detector 3 Quad 2 (W7+W3)")
# dEsum_e_proj_3_2_73.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 3 inPlane E Projection

# %%
det3tE
# Out:
# <ROOT.TCanvas object ("Detector 3 inPlane E Projection") at 0x561750603090>
# Info in <TCanvas::Print>: png file /tmp/tmptj7BBq.png has been created

# %% [markdown]
# Cross section
# ===
# * Previously calculated/estimated to be around .5barns?
# * fixed the issue with counting x number of times. We see about 5x less statistics.
#
# To do:
# ===
# * Cross section
# * Paper
#
# Side note....
# * cluster needs to be taken down during winter break (work being done in the server room).
# * Do we have procedures in place?
