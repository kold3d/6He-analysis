# %% [markdown]
# <sup>6</sup>He(α,α) Analysis Update
# =====================
# March 24, 2017
# --------------------

# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
import rootprint
import rootnotes
import utils

inputFile_out = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out_20170323.root")

# %%
# %%rootprint
# hist = {}
# for h in inputFile_out.GetListOfKeys():
#     h = h.ReadObj()
#
#     hist[h.GetName()] = h

# %%
# %%rootprint
# CMe_vertex_det1 = rootnotes.canvas("CMe_vertex_det1", (696*2,472*3))
# CMe_vertex_det1.Divide(2,3)
#
# CMe_vertex_det1.cd(1)
# hist['CMe_vertex_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['CMe_vertex_1_1_he4'].Draw("colz")
#
# CMe_vertex_det1.cd(2)
# hist['CMe_vertex_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['CMe_vertex_1_2_he4'].Draw("colz")
#
# CMe_vertex_det1.cd(3)
# hist['CMe_vertex_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['CMe_vertex_2_1_he4'].Draw("colz")
#
# CMe_vertex_det1.cd(4)
# hist['CMe_vertex_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['CMe_vertex_2_2_he4'].Draw("colz")
#
# CMe_vertex_det1.cd(5)
# hist['CMe_vertex_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['CMe_vertex_3_1_he4'].Draw("colz")
#
# CMe_vertex_det1.cd(6)
# hist['CMe_vertex_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['CMe_vertex_3_2_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: CMe_vertex_det1

# %% [markdown]
# Last time... we saw a corollation between CM Energy and vertex
# ---

# %%
CMe_vertex_det1
# Out:
# <ROOT.TCanvas object ("CMe_vertex_det1") at 0x7e9b6c0>

# %%
# %%rootprint
# e_vertex_det1 = rootnotes.canvas("e_vertex_det1", (696*2,472*3))
# e_vertex_det1.Divide(2,3)
#
# e_vertex_det1.cd(1)
# hist['e_vertex_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['e_vertex_1_1_he4'].Draw("colz")
#
# e_vertex_det1.cd(2)
# hist['e_vertex_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['e_vertex_1_2_he4'].Draw("colz")
#
# e_vertex_det1.cd(3)
# hist['e_vertex_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['e_vertex_2_1_he4'].Draw("colz")
#
# e_vertex_det1.cd(4)
# hist['e_vertex_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['e_vertex_2_2_he4'].Draw("colz")
#
# e_vertex_det1.cd(5)
# hist['e_vertex_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['e_vertex_3_1_he4'].Draw("colz")
#
# e_vertex_det1.cd(6)
# hist['e_vertex_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['e_vertex_3_2_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: e_vertex_det1

# %% [markdown]
# This corollation exists because vertex position was used to reconstruct CM energies. This corrolation disappears when I plot Lab energy vs Vertex
# ---

# %%
e_vertex_det1
# Out:
# <ROOT.TCanvas object ("e_vertex_det1") at 0x7eb6d10>

# %%
# %%rootprint
# CMe_solidAngle = rootnotes.canvas("cmE vs SolidAngle", (696*2,472*2))
# CMe_solidAngle.Divide(2,2)
#
# CMe_solidAngle.cd(1)
# hist['CMe_SA_region_2'].SetTitle("Region 2")
# hist['CMe_SA_region_2'].Draw("colz")
#
# CMe_solidAngle.cd(2)
# hist['CMe_SA_region_3'].SetTitle("Region 3")
# hist['CMe_SA_region_3'].Draw("colz")
#
# CMe_solidAngle.cd(3)
# hist['CMe_TT_region_2'].SetTitle("Region 2")
# hist['CMe_TT_region_2'].Draw("colz")
#
# CMe_solidAngle.cd(4)
# hist['CMe_TT_region_3'].SetTitle("Region 3")
# hist['CMe_TT_region_3'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: cmE vs SolidAngle

# %%
CMe_solidAngle
# Out:
# <ROOT.TCanvas object ("cmE vs SolidAngle") at 0x7cf0770>

# %%
# %%rootprint
# CS = rootnotes.canvas("cross section by regions", (696*2,472))
# CS.Divide(2,1)
#
# CS.cd(1)
# hist['e_cs_region_2'].SetTitle("Region 2")
# hist['e_cs_region_2'].Draw("colz")
#
# CS.cd(2)
# csHist = hist['e_cs_region_3']
# csHist.SetAxisRange(5. ,9.,"X")
# hist['e_cs_region_3'].SetTitle("Region 3")
#
# hist['e_cs_region_3'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: cross section by regions

# %%
CS
# Out:
# <ROOT.TCanvas object ("cross section by regions") at 0x7be4a80>

# %% [markdown]
# To do:
# ---
# * Offplane wires need to be accounted for, for the bottom quadrants.
