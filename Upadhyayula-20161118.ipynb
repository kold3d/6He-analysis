# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
import rootprint
import rootnotes
import utils

# %%
ROOT.gROOT.Reset()
#Clear all stored canvases/variables

# %%
inputFile_out = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out.root")
inputFile_out_old = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out_old.root")
inputFile_cuts = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/cuts.root")
inputFile_cuts2 = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/cuts_2.root")
inputFile_cal = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/SiCalibration/si_ch_hist.root")

# %%
#    Wire 7    #
dE_E_7_2 = inputFile_out.Get("dE_E_7_2")
dE_E_7_1_1_he6 = inputFile_out.Get("dE_E_7_1_1_he6")
dE_E_7_1_2_he6 = inputFile_out.Get("dE_E_7_1_2_he6")
dE_E_7_1_3_he6 = inputFile_out.Get("dE_E_7_1_4_he6")
dE_E_7_1_4_he6 = inputFile_out.Get("dE_E_7_1_4_he6")

dE_E_7_2_1_he6 = inputFile_out.Get("dE_E_7_2_1_he6")
dE_E_7_2_2_he6 = inputFile_out.Get("dE_E_7_2_2_he6")
dE_E_7_2_3_he6 = inputFile_out.Get("dE_E_7_2_3_he6")
dE_E_7_2_4_he6 = inputFile_out.Get("dE_E_7_2_4_he6")

dE_E_7_3_1_he6 = inputFile_out.Get("dE_E_7_3_1_he6")
dE_E_7_3_2_he6 = inputFile_out.Get("dE_E_7_3_2_he6")
dE_E_7_3_3_he6 = inputFile_out.Get("dE_E_7_3_3_he6")
dE_E_7_3_4_he6 = inputFile_out.Get("dE_E_7_3_4_he6")

#    Wire 8    #
dE_E_8_1_1_he6 = inputFile_out.Get("dE_E_8_1_1_he6")
dE_E_8_1_2_he6 = inputFile_out.Get("dE_E_8_1_2_he6")

dE_E_8_2_1_he6 = inputFile_out.Get("dE_E_8_2_1_he6")
dE_E_8_2_2_he6 = inputFile_out.Get("dE_E_8_2_2_he6")

dE_E_8_3_1_he6 = inputFile_out.Get("dE_E_8_3_1_he6")
dE_E_8_3_2_he6 = inputFile_out.Get("dE_E_8_3_2_he6")

dE_E_3_1_2_he6 = inputFile_out.Get("dE_E_3_1_2_he6")
dE_E_3_1_4_he6 = inputFile_out.Get("dE_E_3_1_4_he6")

#    Wire 3    #
dE_E_3_2_1_he6 = inputFile_out.Get("dE_E_3_2_1_he6")
dE_E_3_2_2_he6 = inputFile_out.Get("dE_E_3_2_2_he6")
dE_E_3_2_3_he6 = inputFile_out.Get("dE_E_3_2_3_he6")
dE_E_3_2_4_he6 = inputFile_out.Get("dE_E_3_2_4_he6")

dE_E_3_3_1_he6 = inputFile_out.Get("dE_E_3_3_1_he6")
dE_E_3_3_3_he6 = inputFile_out.Get("dE_E_3_3_3_he6")

#    Wire 4    #
dE_E_4_1_1_he6 = inputFile_out.Get("dE_E_4_1_1_he6")
dE_E_4_1_2_he6 = inputFile_out.Get("dE_E_4_1_2_he6")

dE_E_4_2_1_he6 = inputFile_out.Get("dE_E_4_2_1_he6")
dE_E_4_2_2_he6 = inputFile_out.Get("dE_E_4_2_2_he6")

dE_E_4_3_1_he6 = inputFile_out.Get("dE_E_4_3_1_he6")
dE_E_4_3_2_he6 = inputFile_out.Get("dE_E_4_3_2_he6")

#    Wire 5    #
dE_E_5_1_1_he6 = inputFile_out.Get("dE_E_5_1_1_he6")
dE_E_5_1_2_he6 = inputFile_out.Get("dE_E_5_1_2_he6")

dE_E_5_2_1_he6 = inputFile_out.Get("dE_E_5_2_1_he6")
dE_E_5_2_2_he6 = inputFile_out.Get("dE_E_5_2_2_he6")

dE_E_5_3_1_he6 = inputFile_out.Get("dE_E_5_3_1_he6")
dE_E_5_3_2_he6 = inputFile_out.Get("dE_E_5_3_2_he6")

#    Energy projections    #
e_proj_3_1_2_he4 = inputFile_out.Get("e_proj_3_1_2_he4")
e_proj_3_1_4_he4 = inputFile_out.Get("e_proj_3_1_4_he4")

e_proj_3_2_1_he4 = inputFile_out.Get("e_proj_3_2_1_he4")
e_proj_3_2_2_he4 = inputFile_out.Get("e_proj_3_2_2_he4")
e_proj_3_2_3_he4 = inputFile_out.Get("e_proj_3_2_3_he4")
e_proj_3_2_4_he4 = inputFile_out.Get("e_proj_3_2_4_he4")

e_proj_3_3_1_he4 = inputFile_out.Get("e_proj_3_3_1_he4")
e_proj_3_3_3_he4 = inputFile_out.Get("e_proj_3_3_3_he4")

#    Old Energy projections    #
e_proj_3_1_2_he4_old = inputFile_out_old.Get("e_proj_3_1_2_he4")

e_proj_3_2_1_he4_old = inputFile_out_old.Get("e_proj_3_2_1_he4")
e_proj_3_2_2_he4_old = inputFile_out_old.Get("e_proj_3_2_2_he4")

e_proj_3_3_1_he4_old = inputFile_out_old.Get("e_proj_3_3_1_he4")

si_ch_1_1 = inputFile_cal.Get("si_ch_1_1")

# %%
### Detector 1 ###
cut712 = inputFile_cuts2.Get("cut712")
cut714 = inputFile_cuts2.Get("cut714")

cut312 = inputFile_cuts2.Get("cut312")
cut314 = inputFile_cuts2.Get("cut314")

cut811 = inputFile_cuts2.Get("cut811")
cut812 = inputFile_cuts2.Get("cut812")

cut411 = inputFile_cuts2.Get("cut411")
cut412 = inputFile_cuts2.Get("cut412")

cut511 = inputFile_cuts2.Get("cut511")
cut512 = inputFile_cuts2.Get("cut512")

### Detector 2 ###
cut721 = inputFile_cuts2.Get("cut721")
cut722 = inputFile_cuts2.Get("cut722")
cut723 = inputFile_cuts2.Get("cut723")
cut724 = inputFile_cuts2.Get("cut724")

cut321 = inputFile_cuts2.Get("cut321")
cut322 = inputFile_cuts2.Get("cut322")
cut323 = inputFile_cuts2.Get("cut323")
cut324 = inputFile_cuts2.Get("cut324")

cut821 = inputFile_cuts2.Get("cut821")
cut822 = inputFile_cuts2.Get("cut822")

cut421 = inputFile_cuts2.Get("cut421")
cut422 = inputFile_cuts2.Get("cut422")

cut521 = inputFile_cuts2.Get("cut521")
cut522 = inputFile_cuts2.Get("cut522")

### Detector 3 ###
cut731 = inputFile_cuts2.Get("cut731")
cut733 = inputFile_cuts2.Get("cut733")

cut331 = inputFile_cuts2.Get("cut331")
cut333 = inputFile_cuts2.Get("cut333")

cut831 = inputFile_cuts2.Get("cut831")
cut832 = inputFile_cuts2.Get("cut832")

cut431 = inputFile_cuts2.Get("cut431")
cut432 = inputFile_cuts2.Get("cut432")

cut531 = inputFile_cuts2.Get("cut531")
cut532 = inputFile_cuts2.Get("cut532")

# %%
# %%rootprint
# c1 = rootnotes.canvas('Detector 1',(696*2,472*3))
# c1.Divide(2,3)
# c1.cd(1).SetLogz()
# dE_E_8_1_1_he6.SetTitle("dE-E Wire 8, Detctor 1 Quad 1")
# dE_E_8_1_1_he6.Draw("colz")
# cut811.SetLineColor(ROOT.kRed)
# cut811.SetLineWidth(3)
# cut811.Draw("same")
#
# c1.cd(2).SetLogz()
# dE_E_8_1_2_he6.SetTitle("dE-E Wire 8, Detctor 1 Quad 2")
# dE_E_8_1_2_he6.Draw("colz")
# cut812.SetLineColor(ROOT.kRed)
# cut812.SetLineWidth(3)
# cut812.Draw("same")
#
# c1.cd(3)
# dE_E_4_1_1_he6.SetTitle("dE-E Wire 4, Detctor 1 Quad 1")
# dE_E_4_1_1_he6.Draw("colz")
# cut411.SetLineColor(ROOT.kRed)
# cut411.SetLineWidth(3)
# cut411.Draw("same")
#
# c1.cd(4)
# dE_E_4_1_2_he6.SetTitle("dE-E Wire 4, Detctor 1 Quad 2")
# dE_E_4_1_2_he6.Draw("colz")
# cut412.SetLineColor(ROOT.kRed)
# cut412.SetLineWidth(3)
# cut412.Draw("same")
#
# c1.cd(5)
# dE_E_5_1_1_he6.SetTitle("dE-E Wire 5, Detctor 1 Quad 1")
# dE_E_5_1_1_he6.Draw("colz")
# cut511.SetLineColor(ROOT.kRed)
# cut511.SetLineWidth(3)
# cut511.Draw("same")
#
# c1.cd(6)
# dE_E_5_1_2_he6.SetTitle("dE-E Wire 5, Detctor 1 Quad 2")
# dE_E_5_1_2_he6.Draw("colz")
# cut512.SetLineColor(ROOT.kRed)
# cut512.SetLineWidth(3)
# cut512.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1

# %% [markdown]
# <sup>6</sup>He(α,α) Analysis Update
# =====================
# November 18, 2016
# --------------------

# %% [markdown]
# Off-Plane wires
# ====
#
# * Until now, we only looked at Wire 7 -> Wire 3
#
# * Today's plots will show the following:
#     * Wire 8 -> 4
#     * Wire 8 -> 5
#     * Total energy projections (and some energy projections with just Wire 7-> 3)
#         * Wire 7 -> 3 + Wire 7 -> 4 + Wire 8 -> 4 + Wire 8 -> 5
#
# * We should also examine the cuts
#         * too tight?
#         * too liberal?
#         * Where is it best to cut?

# %% [markdown]
# # Detector 1

# %%
c1
# Out:
# <ROOT.TCanvas object ("Detector 1") at 0x560b2de6c230>

# %%
# %%rootprint
# c2 = rootnotes.canvas('Det1 E-Projection',(696*2,472))
# c2.Divide(2)
# c2.cd(1).SetLogz()
# e_proj_3_1_2_he4.SetTitle("Det 1 Quad 2 Alpha Energy Projection (Total)")
# e_proj_3_1_2_he4.Draw()
#
# c2.cd(2).SetLogz()
# e_proj_3_1_2_he4_old.SetTitle("Det 1 Quad 2 Alpha Energy Projection (Wire 7->3)")
# e_proj_3_1_2_he4_old.Draw()

# %%
c2
# Out:
# <ROOT.TCanvas object ("Det1 E-Projection") at 0x560b2de07530>

# %%
# %%rootprint
# c3 = rootnotes.canvas('Detector 1',(696*2,472*3))
# c3.Divide(2,3)
# c3.cd(1).SetLogz()
# dE_E_8_2_1_he6.SetTitle("dE-E Wire 8, Detctor 2 Quad 1")
# dE_E_8_2_1_he6.Draw("colz")
# cut821.SetLineColor(ROOT.kRed)
# cut821.SetLineWidth(3)
# cut821.Draw("same")
#
# c3.cd(2).SetLogz()
# dE_E_8_2_2_he6.SetTitle("dE-E Wire 8, Detctor 2 Quad 2")
# dE_E_8_2_2_he6.Draw("colz")
# cut822.SetLineColor(ROOT.kRed)
# cut822.SetLineWidth(3)
# cut822.Draw("same")
#
# c3.cd(3)
# dE_E_4_2_1_he6.SetTitle("dE-E Wire 4, Detctor 2 Quad 1")
# dE_E_4_2_1_he6.Draw("colz")
# cut421.SetLineColor(ROOT.kRed)
# cut421.SetLineWidth(3)
# cut421.Draw("same")
#
# c3.cd(4)
# dE_E_4_2_2_he6.SetTitle("dE-E Wire 4, Detctor 2 Quad 2")
# dE_E_4_2_2_he6.Draw("colz")
# cut422.SetLineColor(ROOT.kRed)
# cut422.SetLineWidth(3)
# cut422.Draw("same")
#
# c3.cd(5)
# dE_E_5_2_1_he6.SetTitle("dE-E Wire 5, Detctor 2 Quad 1")
# dE_E_5_2_1_he6.Draw("colz")
# cut421.SetLineColor(ROOT.kRed)
# cut421.SetLineWidth(3)
# cut421.Draw("same")
#
# c3.cd(6)
# dE_E_5_2_2_he6.SetTitle("dE-E Wire 5, Detctor 2 Quad 2")
# dE_E_5_2_2_he6.Draw("colz")
# cut522.SetLineColor(ROOT.kRed)
# cut522.SetLineWidth(3)
# cut522.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1

# %% [markdown]
# # Detector 2

# %%
c3
# Out:
# <ROOT.TCanvas object ("Detector 1") at 0x560b2de3a4c0>

# %%
# %%rootprint
# c3_2 = rootnotes.canvas('Detector 1',(696*2,472*2))
# c3_2.Divide(2,2)
# c3_2.cd(1).SetLogz()
# dE_E_7_2_1_he6.SetTitle("dE-E Wire 7, Detctor 2 Quad 1")
# dE_E_7_2_1_he6.Draw("colz")
# cut721.SetLineColor(ROOT.kRed)
# cut721.SetLineWidth(3)
# cut721.Draw("same")
#
# c3_2.cd(2).SetLogz()
# dE_E_7_2_2_he6.SetTitle("dE-E Wire 7, Detctor 2 Quad 2")
# dE_E_7_2_2_he6.Draw("colz")
# cut722.SetLineColor(ROOT.kRed)
# cut722.SetLineWidth(3)
# cut722.Draw("same")
#
# c3_2.cd(3)
# dE_E_3_2_1_he6.SetTitle("dE-E Wire 3, Detctor 2 Quad 1")
# dE_E_3_2_1_he6.Draw("colz")
# cut321.SetLineColor(ROOT.kRed)
# cut321.SetLineWidth(3)
# cut321.Draw("same")
#
# c3_2.cd(4)
# dE_E_3_2_2_he6.SetTitle("dE-E Wire 3, Detctor 2 Quad 2")
# dE_E_3_2_2_he6.Draw("colz")
# cut322.SetLineColor(ROOT.kRed)
# cut322.SetLineWidth(3)
# cut322.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1

# %%
c3_2
# Out:
# <ROOT.TCanvas object ("Detector 1") at 0x560b2de66130>

# %%
# %%rootprint
# c4 = rootnotes.canvas('Det2 E-Projection',(696*2,472*2))
# c4.Divide(2,2)
# c4.cd(1)
# e_proj_3_2_1_he4.SetTitle("Det 2 Quad 1 Alpha Energy Projection (Total)")
# e_proj_3_2_1_he4.Draw()
#
# c4.cd(2)
# e_proj_3_2_1_he4_old.SetTitle("Det 1 Quad 1 Alpha Energy Projection (Wire 7->3)")
# e_proj_3_2_1_he4_old.Draw()
#
# c4.cd(3)
# e_proj_3_2_2_he4.SetTitle("Det 2 Quad 2 Alpha Energy Projection (Total)")
# e_proj_3_2_2_he4.Draw()
#
# c4.cd(4)
# # e_proj_3_2_2_he4_old.SetTitle("Det 2 Quad 2 Alpha Energy Projection (Wire 7->3)")
# # e_proj_3_2_2_he4_old.Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Det2 E-Projection

# %%
c4
# Out:
# <ROOT.TCanvas object ("Det2 E-Projection") at 0x560b2de7d1f0>

# %%
# %%rootprint
# c5 = rootnotes.canvas('Detector 3',(696*2,472*3))
# c5.Divide(2,3)
# c5.cd(1).SetLogz()
# dE_E_8_3_1_he6.SetTitle("dE-E Wire 8, Detctor 3 Quad 1")
# dE_E_8_3_1_he6.Draw("colz")
# cut831.SetLineColor(ROOT.kRed)
# cut831.SetLineWidth(3)
# cut831.Draw("same")
#
# c5.cd(2).SetLogz()
# dE_E_8_3_2_he6.SetTitle("dE-E Wire 8, Detctor 3 Quad 2")
# dE_E_8_3_2_he6.Draw("colz")
# cut832.SetLineColor(ROOT.kRed)
# cut832.SetLineWidth(3)
# cut832.Draw("same")
#
# c5.cd(3)
# dE_E_4_3_1_he6.SetTitle("dE-E Wire 4, Detctor 3 Quad 1")
# dE_E_4_3_1_he6.Draw("colz")
# cut431.SetLineColor(ROOT.kRed)
# cut431.SetLineWidth(3)
# cut431.Draw("same")
#
# c5.cd(4)
# dE_E_4_3_2_he6.SetTitle("dE-E Wire 4, Detctor 3 Quad 2")
# dE_E_4_3_2_he6.Draw("colz")
# cut432.SetLineColor(ROOT.kRed)
# cut432.SetLineWidth(3)
# cut432.Draw("same")
#
# c5.cd(5)
# dE_E_5_3_1_he6.SetTitle("dE-E Wire 5, Detctor 3 Quad 1")
# dE_E_5_3_1_he6.Draw("colz")
# cut431.SetLineColor(ROOT.kRed)
# cut431.SetLineWidth(3)
# cut431.Draw("same")
#
# c5.cd(6)
# dE_E_5_3_2_he6.SetTitle("dE-E Wire 5, Detctor 3 Quad 2")
# dE_E_5_3_2_he6.Draw("colz")
# cut532.SetLineColor(ROOT.kRed)
# cut532.SetLineWidth(3)
# cut532.Draw("same")

# %% [markdown]
# # Detector 3

# %%
c5
# Out:
# <ROOT.TCanvas object ("Detector 3") at 0x560b2de72e70>

# %%
# %%rootprint
# c6 = rootnotes.canvas('Det3 E-Projection',(696*2,472))
# c6.Divide(2)
# c6.cd(1).SetLogz()
# e_proj_3_3_1_he4.SetTitle("Det 3 Quad 2 Alpha Energy Projection (Total)")
# e_proj_3_3_1_he4.Draw()
#
# c6.cd(2).SetLogz()
# e_proj_3_3_1_he4_old.SetTitle("Det 3 Quad 2 Alpha Energy Projection (Wire 7->3)")
# e_proj_3_3_1_he4_old.Draw()

# %%
c6
# Out:
# <ROOT.TCanvas object ("Det3 E-Projection") at 0x560b2de6ff20>

# %% [markdown]
# Conclusion and to do:
# ===
#
# * With the new wires added into to the spectra, the overall features do not change.
# * Should the cuts be re done?
# * Should this be repeated for the lower quadrants?
#     * Also, do the same for low pressure runs?
# * What should be the next step moving forward?
