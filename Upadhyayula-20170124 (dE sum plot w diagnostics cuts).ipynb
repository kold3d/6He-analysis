# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
import rootprint
import rootnotes
import utils

# %%
inputFile_out_dEsum73_lower = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out73_lower.root")
inputFile_out_dEsum73_middle = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out73_middle.root")
inputFile_out_dEsum73_upper = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out73_upper.root")

inputFile_dEcuts = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/cuts_diagnostics.root")

# %%
# %%rootprint
# dESum_cuts = {}
# for h in inputFile_dEcuts.GetListOfKeys():
#     h = h.ReadObj()
# #     if h.ClassName() == TCutG
#     dESum_cuts[h.GetName()] = h

# %%
hist_lower = {}
for h in inputFile_out_dEsum73_lower.GetListOfKeys():
    h = h.ReadObj()
    hist_lower[h.GetName()] = h
    
hist_middle = {}
for h in inputFile_out_dEsum73_middle.GetListOfKeys():
    h = h.ReadObj()
    hist_middle[h.GetName()] = h
    
hist_upper = {}
for h in inputFile_out_dEsum73_upper.GetListOfKeys():
    h = h.ReadObj()
    hist_upper[h.GetName()] = h

# %%
print hist_lower['dEsum_E_7_3_1_1']
# Out:
# <ROOT.TH2F object ("dEsum_E_7_3_1_1") at 0x12806260>

# %%
# %%rootprint
# det1quad1 = rootnotes.canvas('Detector 1 inPlane', (696*2,472*2))
# det1quad1.Divide(2,2)
# det1quad1.cd(1)
# hist_lower['dEsum_E_7_3_1_1'].SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 1")
# hist_lower['dEsum_E_7_3_1_1'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73011'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73011'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73111'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73111'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73211'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73211'].Draw("same")
#
# det1quad1.cd(2)
# hist_upper['dE_E_7_1_1'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 1 - upper band ")
# hist_upper['dE_E_7_1_1'].Draw("colz")
#
# det1quad1.cd(3)
# hist_middle['dE_E_7_1_1'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 1 - middle band ")
# hist_middle['dE_E_7_1_1'].Draw("colz")
#
#
# det1quad1.cd(4)
# hist_lower['dE_E_7_1_1'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 1 - lower band ")
# hist_lower['dE_E_7_1_1'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane

# %%
det1quad1
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane") at 0x14697480>

# %%
# %%rootprint
# det1quad2 = rootnotes.canvas('Detector 1 inPlane', (696*2,472*2))
# det1quad2.Divide(2,2)
# det1quad2.cd(1)
# hist_lower['dEsum_E_7_3_1_2'].SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 2")
# hist_lower['dEsum_E_7_3_1_2'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73012'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73012'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73112'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73112'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73212'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73212'].Draw("same")
#
# det1quad2.cd(2)
# hist_upper['dE_E_7_1_2'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 2 - upper band ")
# hist_upper['dE_E_7_1_2'].Draw("colz")
#
# det1quad2.cd(3)
# hist_middle['dE_E_7_1_2'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 2 - middle band ")
# hist_middle['dE_E_7_1_2'].Draw("colz")
#
#
# det1quad2.cd(4)
# hist_lower['dE_E_7_1_2'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 2 - lower band ")
# hist_lower['dE_E_7_1_2'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane

# %%
det1quad2
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane") at 0x7259710>

# %%
# %%rootprint
# det1quad3 = rootnotes.canvas('Detector 1 inPlane', (696*2,472*2))
# det1quad3.Divide(2,2)
# det1quad3.cd(1)
# hist_lower['dEsum_E_7_3_1_3'].SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 3")
# hist_lower['dEsum_E_7_3_1_3'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73013'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73013'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73113'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73113'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73213'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73213'].Draw("same")
#
# det1quad3.cd(2)
# hist_upper['dE_E_7_1_3'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 3 - upper band ")
# hist_upper['dE_E_7_1_3'].Draw("colz")
#
# det1quad3.cd(3)
# hist_middle['dE_E_7_1_3'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 3 - middle band ")
# hist_middle['dE_E_7_1_3'].Draw("colz")
#
#
# det1quad3.cd(4)
# hist_lower['dE_E_7_1_3'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 3 - lower band ")
# hist_lower['dE_E_7_1_3'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane

# %%
det1quad3
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane") at 0x14668160>

# %%
# %%rootprint
# det1quad4 = rootnotes.canvas('Detector 1 inPlane', (696*2,472*2))
# det1quad4.Divide(2,2)
# det1quad4.cd(1)
# hist_lower['dEsum_E_7_3_1_4'].SetTitle("dE(W7+W3) vs. E, Detctor 1 Quad 4")
# hist_lower['dEsum_E_7_3_1_4'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73014'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73014'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73114'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73114'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73214'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73214'].Draw("same")
#
# det1quad4.cd(2)
# hist_upper['dE_E_7_1_4'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 4 - upper band ")
# hist_upper['dE_E_7_1_4'].Draw("colz")
#
# det1quad4.cd(3)
# hist_middle['dE_E_7_1_4'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 4 - middle band ")
# hist_middle['dE_E_7_1_4'].Draw("colz")
#
#
# det1quad4.cd(4)
# hist_lower['dE_E_7_1_4'].SetTitle("dE(wire7) vs. E, Detctor 1 Quad 4 - lower band ")
# hist_lower['dE_E_7_1_4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Detector 1 inPlane

# %%
det1quad4
# Out:
# <ROOT.TCanvas object ("Detector 1 inPlane") at 0x14664e20>

# %%
# %%rootprint
# det2quad1 = rootnotes.canvas('Detector 2 quad 1 inPlane', (696*2,472*2))
# det2quad1.Divide(2,2)
# det2quad1.cd(1)
# hist_lower['dEsum_E_7_3_2_1'].SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 1")
# hist_lower['dEsum_E_7_3_2_1'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73021'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73021'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73121'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73121'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73221'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73221'].Draw("same")
#
# det2quad1.cd(2)
# hist_upper['dE_E_7_2_1'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 1 - upper band ")
# hist_upper['dE_E_7_2_1'].Draw("colz")
#
# det2quad1.cd(3)
# hist_middle['dE_E_7_2_1'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 1 - middle band ")
# hist_middle['dE_E_7_2_1'].Draw("colz")
#
#
# det2quad1.cd(4)
# hist_lower['dE_E_7_2_1'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 1 - lower band ")
# hist_lower['dE_E_7_2_1'].Draw("colz")

# %%
det2quad1
# Out:
# <ROOT.TCanvas object ("Detector 2 quad 1 inPlane") at 0x14734500>

# %%
# %%rootprint
# det2quad2 = rootnotes.canvas('Detector 2 quad 2 inPlane', (696*2,472*2))
# det2quad2.Divide(2,2)
# det2quad2.cd(1)
# hist_lower['dEsum_E_7_3_2_2'].SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 2")
# hist_lower['dEsum_E_7_3_2_2'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73022'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73022'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73122'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73122'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73222'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73222'].Draw("same")
#
# det2quad2.cd(2)
# hist_upper['dE_E_7_2_2'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 2 - upper band ")
# hist_upper['dE_E_7_2_2'].Draw("colz")
#
# det2quad2.cd(3)
# hist_middle['dE_E_7_2_2'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 2 - middle band ")
# hist_middle['dE_E_7_2_2'].Draw("colz")
#
#
# det2quad2.cd(4)
# hist_lower['dE_E_7_2_2'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 2 - lower band ")
# hist_lower['dE_E_7_2_2'].Draw("colz")

# %%
det2quad2
# Out:
# <ROOT.TCanvas object ("Detector 2 quad 2 inPlane") at 0x14750480>

# %%
# %%rootprint
# det2quad3 = rootnotes.canvas('Detector 2 quad 3 inPlane', (696*2,472*2))
# det2quad3.Divide(2,2)
# det2quad3.cd(1)
# hist_lower['dEsum_E_7_3_2_3'].SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 3")
# hist_lower['dEsum_E_7_3_2_3'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73023'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73023'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73123'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73123'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73223'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73223'].Draw("same")
#
# det2quad3.cd(2)
# hist_upper['dE_E_7_2_3'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 3 - upper band ")
# hist_upper['dE_E_7_2_3'].Draw("colz")
#
# det2quad3.cd(3)
# hist_middle['dE_E_7_2_3'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 3 - middle band ")
# hist_middle['dE_E_7_2_3'].Draw("colz")
#
#
# det2quad3.cd(4)
# hist_lower['dE_E_7_2_3'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 3 - lower band ")
# hist_lower['dE_E_7_2_3'].Draw("colz")

# %%
det2quad3
# Out:
# <ROOT.TCanvas object ("Detector 2 quad 3 inPlane") at 0x14741e00>

# %%
# %%rootprint
# det2quad4 = rootnotes.canvas('Detector 2 quad 4 inPlane', (696*2,472*2))
# det2quad4.Divide(2,2)
# det2quad4.cd(1)
# hist_lower['dEsum_E_7_3_2_4'].SetTitle("dE(W7+W3) vs. E, Detctor 2 Quad 4")
# hist_lower['dEsum_E_7_3_2_4'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73024'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73024'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73124'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73124'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73224'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73224'].Draw("same")
#
# det2quad4.cd(2)
# hist_upper['dE_E_7_2_4'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 4 - upper band ")
# hist_upper['dE_E_7_2_4'].Draw("colz")
#
# det2quad4.cd(3)
# hist_middle['dE_E_7_2_4'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 4 - middle band ")
# hist_middle['dE_E_7_2_4'].Draw("colz")
#
#
# det2quad4.cd(4)
# hist_lower['dE_E_7_2_4'].SetTitle("dE(wire7) vs. E, Detctor 2 Quad 4 - lower band ")
# hist_lower['dE_E_7_2_4'].Draw("colz")

# %%
det2quad4
# Out:
# <ROOT.TCanvas object ("Detector 2 quad 4 inPlane") at 0x1472f950>

# %%
# %%rootprint
# det3quad1 = rootnotes.canvas('Detector 3 quad 1 inPlane', (696*2,472*2))
# det3quad1.Divide(2,2)
# det3quad1.cd(1)
# hist_lower['dEsum_E_7_3_3_1'].SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 1")
# hist_lower['dEsum_E_7_3_3_1'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73031'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73031'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73131'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73131'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73231'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73231'].Draw("same")
#
# det3quad1.cd(2)
# hist_upper['dE_E_7_3_1'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 1 - upper band ")
# hist_upper['dE_E_7_3_1'].Draw("colz")
#
# det3quad1.cd(3)
# hist_middle['dE_E_7_3_1'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 1 - middle band ")
# hist_middle['dE_E_7_3_1'].Draw("colz")
#
#
# det3quad1.cd(4)
# hist_lower['dE_E_7_3_1'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 1 - lower band ")
# hist_lower['dE_E_7_3_1'].Draw("colz")

# %%
det3quad1
# Out:
# <ROOT.TCanvas object ("Detector 3 quad 1 inPlane") at 0x1472ef30>

# %%
# %%rootprint
# det3quad2 = rootnotes.canvas('Detector 3 quad 2 inPlane', (696*2,472*2))
# det3quad2.Divide(2,2)
# det3quad2.cd(1)
# hist_lower['dEsum_E_7_3_3_2'].SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 2")
# hist_lower['dEsum_E_7_3_3_2'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73032'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73032'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73132'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73132'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73232'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73232'].Draw("same")
#
# det3quad2.cd(2)
# hist_upper['dE_E_7_3_2'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 2 - upper band ")
# hist_upper['dE_E_7_3_2'].Draw("colz")
#
# det3quad2.cd(3)
# hist_middle['dE_E_7_3_2'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 2 - middle band ")
# hist_middle['dE_E_7_3_2'].Draw("colz")
#
#
# det3quad2.cd(4)
# hist_lower['dE_E_7_3_2'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 2 - lower band ")
# hist_lower['dE_E_7_3_2'].Draw("colz")

# %%
det3quad2
# Out:
# <ROOT.TCanvas object ("Detector 3 quad 2 inPlane") at 0x7a60860>

# %%
# %%rootprint
# det3quad3 = rootnotes.canvas('Detector 3 quad 3 inPlane', (696*2,472*2))
# det3quad3.Divide(2,2)
# det3quad3.cd(1)
# hist_lower['dEsum_E_7_3_3_3'].SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 3")
# hist_lower['dEsum_E_7_3_3_3'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73033'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73033'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73133'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73133'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73233'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73233'].Draw("same")
#
# det3quad3.cd(2)
# hist_upper['dE_E_7_3_3'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 3 - upper band ")
# hist_upper['dE_E_7_3_3'].Draw("colz")
#
# det3quad3.cd(3)
# hist_middle['dE_E_7_3_3'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 3 - middle band ")
# hist_middle['dE_E_7_3_3'].Draw("colz")
#
#
# det3quad3.cd(4)
# hist_lower['dE_E_7_3_3'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 3 - lower band ")
# hist_lower['dE_E_7_3_3'].Draw("colz")

# %%
det3quad3
# Out:
# <ROOT.TCanvas object ("Detector 3 quad 3 inPlane") at 0x146fc060>

# %%
# %%rootprint
# det3quad4 = rootnotes.canvas('Detector 3 quad 4 inPlane', (696*2,472*2))
# det3quad4.Divide(2,2)
# det3quad4.cd(1)
# hist_lower['dEsum_E_7_3_3_4'].SetTitle("dE(W7+W3) vs. E, Detctor 3 Quad 4")
# hist_lower['dEsum_E_7_3_3_4'].Draw("colz")
#
# dESum_cuts['cut_diagnostics_73034'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73034'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73134'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73134'].Draw("same")
#
# dESum_cuts['cut_diagnostics_73234'].SetLineColor(ROOT.kRed)
# dESum_cuts['cut_diagnostics_73234'].Draw("same")
#
# det3quad4.cd(2)
# hist_upper['dE_E_7_3_4'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 4 - upper band ")
# hist_upper['dE_E_7_3_4'].Draw("colz")
#
# det3quad4.cd(3)
# hist_middle['dE_E_7_3_4'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 4 - middle band ")
# hist_middle['dE_E_7_3_4'].Draw("colz")
#
#
# det3quad4.cd(4)
# hist_lower['dE_E_7_3_4'].SetTitle("dE(wire7) vs. E, Detctor 3 Quad 4 - lower band ")
# hist_lower['dE_E_7_3_4'].Draw("colz")

# %%
det3quad4
# Out:
# <ROOT.TCanvas object ("Detector 3 quad 4 inPlane") at 0x14750ea0>
