# %% [markdown]
# <sup>6</sup>He(α,α) Analysis Update
# =====================
# May 12, 2017
# --------------------

# %% [markdown]
# * Fixed Position in wires
# ====
#
# * Made cuts and histograms for the lower quadrants
# ----

# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F
import rootprint
import rootnotes
import utils

inputFile_out = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out.root")
inputFile_cuts2 = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/cuts_2.root")

# %%
# %%rootprint
# hist = {}
# for h in inputFile_out.GetListOfKeys():
#     h = h.ReadObj()
#
#     hist[h.GetName()] = h
# #     print h

# %%
### Detector 1 ###
cut711 = inputFile_cuts2.Get("cut711")
cut712 = inputFile_cuts2.Get("cut712")
cut713 = inputFile_cuts2.Get("cut713")
cut714 = inputFile_cuts2.Get("cut714")

cut311 = inputFile_cuts2.Get("cut311")
cut312 = inputFile_cuts2.Get("cut312")
cut313 = inputFile_cuts2.Get("cut313")
cut314 = inputFile_cuts2.Get("cut314")

cut811 = inputFile_cuts2.Get("cut811")
cut812 = inputFile_cuts2.Get("cut812")

cut411 = inputFile_cuts2.Get("cut411")
cut412 = inputFile_cuts2.Get("cut412")

cut511 = inputFile_cuts2.Get("cut511")
cut512 = inputFile_cuts2.Get("cut512")

cut613 = inputFile_cuts2.Get("cut613")
cut614 = inputFile_cuts2.Get("cut614")

cut213 = inputFile_cuts2.Get("cut213")
cut214 = inputFile_cuts2.Get("cut214")

### Detector 2 ###
cut721 = inputFile_cuts2.Get("cut721")
cut722 = inputFile_cuts2.Get("cut722")
cut723 = inputFile_cuts2.Get("cut723")
cut724 = inputFile_cuts2.Get("cut724")

cut321 = inputFile_cuts2.Get("cut321")
cut322 = inputFile_cuts2.Get("cut322")
cut323 = inputFile_cuts2.Get("cut323")
cut324 = inputFile_cuts2.Get("cut324")

cut821 = inputFile_cuts2.Get("cut821")
cut822 = inputFile_cuts2.Get("cut822")

cut421 = inputFile_cuts2.Get("cut421")
cut422 = inputFile_cuts2.Get("cut422")

cut521 = inputFile_cuts2.Get("cut521")
cut522 = inputFile_cuts2.Get("cut522")

cut623 = inputFile_cuts2.Get("cut623")
cut624 = inputFile_cuts2.Get("cut624")

cut223 = inputFile_cuts2.Get("cut223")
cut224 = inputFile_cuts2.Get("cut224")

### Detector 3 ###
cut731 = inputFile_cuts2.Get("cut731")
cut732 = inputFile_cuts2.Get("cut732")
cut733 = inputFile_cuts2.Get("cut733")
cut734 = inputFile_cuts2.Get("cut734")

cut331 = inputFile_cuts2.Get("cut331")
cut333 = inputFile_cuts2.Get("cut333")

cut831 = inputFile_cuts2.Get("cut831")
cut832 = inputFile_cuts2.Get("cut832")

cut431 = inputFile_cuts2.Get("cut431")
cut432 = inputFile_cuts2.Get("cut432")

cut531 = inputFile_cuts2.Get("cut531")
cut532 = inputFile_cuts2.Get("cut532")

cut633 = inputFile_cuts2.Get("cut633")
cut634 = inputFile_cuts2.Get("cut634")

cut233 = inputFile_cuts2.Get("cut233")
cut234 = inputFile_cuts2.Get("cut234")

# %%
# %%rootprint
# front_back_pos= rootnotes.canvas("front_back_pos", (696*2,472*3))
# front_back_pos.Divide(2,3)
#
# front_back_pos.cd(1)
# hist['frontWirePos_backWirePos_7_3_he4'].SetTitle("Wire 7 vs. Wire 3 Position")
# hist['frontWirePos_backWirePos_7_3_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_7_3_he4'].SetStats(0)
#
# front_back_pos.cd(2)
# hist['frontWirePos_backWirePos_7_4_he4'].SetTitle("Wire 7 vs. Wire 4 Position")
# hist['frontWirePos_backWirePos_7_4_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_7_4_he4'].SetStats(0)
#
# front_back_pos.cd(3)
# hist['frontWirePos_backWirePos_8_4_he4'].SetTitle("Wire 8 vs. Wire 4 Position")
# hist['frontWirePos_backWirePos_8_4_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_8_4_he4'].SetStats(0)
#
# front_back_pos.cd(4)
# hist['frontWirePos_backWirePos_8_5_he4'].SetTitle("Wire 8 vs. Wire 5 Position")
# hist['frontWirePos_backWirePos_8_5_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_8_5_he4'].SetStats(0)
#
# front_back_pos.cd(5)
# hist['frontWirePos_backWirePos_7_2_he4'].SetTitle("Wire 7 vs. Wire 2 Position")
# hist['frontWirePos_backWirePos_7_2_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_7_2_he4'].SetStats(0)
#
# front_back_pos.cd(6)
# hist['frontWirePos_backWirePos_6_2_he4'].SetTitle("Wire 6 vs. Wire 2 Position")
# hist['frontWirePos_backWirePos_6_2_he4'].Draw("colz")
# hist['frontWirePos_backWirePos_6_2_he4'].SetStats(0)
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: front_back_pos

# %% [markdown]
# Position (front wire) vs. Position ( back wire)
# ----

# %%
front_back_pos
# Out:
# <ROOT.TCanvas object ("front_back_pos") at 0x627d730>

# %%
# %%rootprint
# wire6 = rootnotes.canvas("wire7Pos", (696*2,472*3))
# wire6.Divide(2,3)
#
# wire6.cd(1)
# hist['e_wirePos_6_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire6 Pos")
# hist['e_wirePos_6_1_3_he4'].Draw("colz")
#
# wire6.cd(2)
# hist['e_wirePos_6_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire6 Pos")
# hist['e_wirePos_6_1_4_he4'].Draw("colz")
#
# wire6.cd(3)
# hist['e_wirePos_6_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire6 Pos")
# hist['e_wirePos_6_2_3_he4'].Draw("colz")
#
# wire6.cd(4)
# hist['e_wirePos_6_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire6 Pos")
# hist['e_wirePos_6_2_4_he4'].Draw("colz")
#
# wire6.cd(5)
# hist['e_wirePos_6_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire6 Pos")
# hist['e_wirePos_6_3_3_he4'].Draw("colz")
#
# wire6.cd(6)
# hist['e_wirePos_6_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire6 Pos")
# hist['e_wirePos_6_3_4_he4'].Draw("colz")

# %% [markdown]
# Positions in individual wires
# ----

# %%
wire6
# Out:
# <ROOT.TCanvas object ("wire7Pos") at 0x7979440>

# %%
# %%rootprint
# wire7 = rootnotes.canvas("wire7Pos", (696*2,472*6))
# wire7.Divide(2,6)
#
# wire7.cd(1)
# hist['e_wirePos_7_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire7 Pos")
# hist['e_wirePos_7_1_1_he4'].Draw("colz")
#
# wire7.cd(2)
# hist['e_wirePos_7_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire7 Pos")
# hist['e_wirePos_7_1_2_he4'].Draw("colz")
#
# wire7.cd(3)
# hist['e_wirePos_7_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire7 Pos")
# hist['e_wirePos_7_1_3_he4'].Draw("colz")
#
# wire7.cd(4)
# hist['e_wirePos_7_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire7 Pos")
# hist['e_wirePos_7_1_4_he4'].Draw("colz")
#
# wire7.cd(5)
# hist['e_wirePos_7_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire7 Pos")
# hist['e_wirePos_7_2_1_he4'].Draw("colz")
#
# wire7.cd(6)
# hist['e_wirePos_7_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire7 Pos")
# hist['e_wirePos_7_2_2_he4'].Draw("colz")
#
# wire7.cd(7)
# hist['e_wirePos_7_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire7 Pos")
# hist['e_wirePos_7_2_3_he4'].Draw("colz")
#
# wire7.cd(8)
# hist['e_wirePos_7_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire7 Pos")
# hist['e_wirePos_7_2_4_he4'].Draw("colz")
#
# wire7.cd(9)
# hist['e_wirePos_7_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire7 Pos")
# hist['e_wirePos_7_3_1_he4'].Draw("colz")
#
# wire7.cd(10)
# hist['e_wirePos_7_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire7 Pos")
# hist['e_wirePos_7_3_2_he4'].Draw("colz")
#
# wire7.cd(11)
# hist['e_wirePos_7_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire7 Pos")
# hist['e_wirePos_7_3_3_he4'].Draw("colz")
#
# wire7.cd(12)
# hist['e_wirePos_7_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire7 Pos")
# hist['e_wirePos_7_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire7Pos

# %%
wire7
# Out:
# <ROOT.TCanvas object ("wire7Pos") at 0x7e59a90>

# %%
# %%rootprint
# wire8 = rootnotes.canvas("wire8Pos", (696*2,472*3))
# wire8.Divide(2,3)
#
# wire8.cd(1)
# hist['e_wirePos_8_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire8 Pos")
# hist['e_wirePos_8_1_1_he4'].Draw("colz")
#
# wire8.cd(2)
# hist['e_wirePos_8_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire8 Pos")
# hist['e_wirePos_8_1_2_he4'].Draw("colz")
#
# wire8.cd(3)
# hist['e_wirePos_8_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire8 Pos")
# hist['e_wirePos_8_2_1_he4'].Draw("colz")
#
# wire8.cd(4)
# hist['e_wirePos_8_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire8 Pos")
# hist['e_wirePos_8_2_2_he4'].Draw("colz")
#
# wire8.cd(5)
# hist['e_wirePos_8_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire8 Pos")
# hist['e_wirePos_8_3_1_he4'].Draw("colz")
#
# wire8.cd(6)
# hist['e_wirePos_8_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire8 Pos")
# hist['e_wirePos_8_3_2_he4'].Draw("colz")

# %%
wire8
# Out:
# <ROOT.TCanvas object ("wire8Pos") at 0x7f4bb30>

# %%
# %%rootprint
# wire2 = rootnotes.canvas("wire7Pos", (696*2,472*3))
# wire2.Divide(2,3)
#
# wire2.cd(1)
# hist['e_wirePos_2_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire2 Pos")
# hist['e_wirePos_2_1_3_he4'].Draw("colz")
#
# wire2.cd(2)
# hist['e_wirePos_2_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire2 Pos")
# hist['e_wirePos_2_1_4_he4'].Draw("colz")
#
# wire2.cd(3)
# hist['e_wirePos_2_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire2 Pos")
# hist['e_wirePos_2_2_3_he4'].Draw("colz")
#
# wire2.cd(4)
# hist['e_wirePos_2_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire2 Pos")
# hist['e_wirePos_2_2_4_he4'].Draw("colz")
#
# wire2.cd(5)
# hist['e_wirePos_2_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire2 Pos")
# hist['e_wirePos_2_3_3_he4'].Draw("colz")
#
# wire2.cd(6)
# hist['e_wirePos_2_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire2 Pos")
# hist['e_wirePos_2_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire7Pos

# %%
wire2
# Out:
# <ROOT.TCanvas object ("wire7Pos") at 0x7f3af00>

# %%
# %%rootprint
# wire3 = rootnotes.canvas("wire3Pos", (696*2,472*3))
# wire3.Divide(2,3)
#
# wire3.cd(1)
# hist['e_wirePos_3_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire3 Pos")
# hist['e_wirePos_3_1_1_he4'].Draw("colz")
#
# wire3.cd(2)
# hist['e_wirePos_3_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire3 Pos")
# hist['e_wirePos_3_1_2_he4'].Draw("colz")
#
# wire3.cd(3)
# hist['e_wirePos_3_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire3 Pos")
# hist['e_wirePos_3_2_1_he4'].Draw("colz")
#
# wire3.cd(4)
# hist['e_wirePos_3_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire3 Pos")
# hist['e_wirePos_3_2_2_he4'].Draw("colz")
#
# wire3.cd(5)
# hist['e_wirePos_3_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire3 Pos")
# hist['e_wirePos_3_3_1_he4'].Draw("colz")
#
# wire3.cd(6)
# hist['e_wirePos_3_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire3 Pos")
# hist['e_wirePos_3_3_2_he4'].Draw("colz")

# %%
wire3
# Out:
# <ROOT.TCanvas object ("wire3Pos") at 0x7fa9cc0>

# %%
# %%rootprint
# wire4 = rootnotes.canvas("wire4Pos", (696*2,472*3))
# wire4.Divide(2,3)
#
# wire4.cd(1)
# hist['e_wirePos_4_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire4 Pos")
# hist['e_wirePos_4_1_1_he4'].Draw("colz")
#
# wire4.cd(2)
# hist['e_wirePos_4_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire4 Pos")
# hist['e_wirePos_4_1_2_he4'].Draw("colz")
#
# wire4.cd(3)
# hist['e_wirePos_4_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire4 Pos")
# hist['e_wirePos_4_2_1_he4'].Draw("colz")
#
# wire4.cd(4)
# hist['e_wirePos_4_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire4 Pos")
# hist['e_wirePos_4_2_2_he4'].Draw("colz")
#
# wire4.cd(5)
# hist['e_wirePos_4_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire4 Pos")
# hist['e_wirePos_4_3_1_he4'].Draw("colz")
#
# wire4.cd(6)
# hist['e_wirePos_4_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire4 Pos")
# hist['e_wirePos_4_3_2_he4'].Draw("colz")

# %%
wire4
# Out:
# <ROOT.TCanvas object ("wire4Pos") at 0x7f82300>

# %%
# %%rootprint
# wire5 = rootnotes.canvas("wire4Pos", (696*2,472*3))
# wire5.Divide(2,3)
#
# wire5.cd(1)
# hist['e_wirePos_5_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire5 Pos")
# hist['e_wirePos_5_1_1_he4'].Draw("colz")
#
# wire5.cd(2)
# hist['e_wirePos_5_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire5 Pos")
# hist['e_wirePos_5_1_2_he4'].Draw("colz")
#
# wire5.cd(3)
# hist['e_wirePos_5_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire5 Pos")
# hist['e_wirePos_5_2_1_he4'].Draw("colz")
#
# wire5.cd(4)
# hist['e_wirePos_5_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire5 Pos")
# hist['e_wirePos_5_2_2_he4'].Draw("colz")
#
# wire5.cd(5)
# hist['e_wirePos_5_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire5 Pos")
# hist['e_wirePos_5_3_1_he4'].Draw("colz")
#
# wire5.cd(6)
# hist['e_wirePos_5_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire5 Pos")
# hist['e_wirePos_5_3_2_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire4Pos

# %%
wire5
# Out:
# <ROOT.TCanvas object ("wire4Pos") at 0x7fa91e0>

# %% [markdown]
# dE-E plots and E spectra for lower quadrants
# ----

# %%
# %%rootprint
# p1 = rootnotes.canvas('Plane Detector 1',(696*2,472*2))
# p1.Divide(2,2)
#
# p1.cd(1)
# hist["dE_E_7_1_3"].SetTitle("dE-E Wire 7, Detctor 1 Quad 3")
# hist["dE_E_7_1_3"].Draw("colz")
# cut713.SetLineColor(ROOT.kRed)
# cut713.SetLineWidth(3)
# cut713.Draw("same")
#
# p1.cd(2)
# hist["dE_E_6_1_3"].SetTitle("dE-E Wire 6, Detctor 1 Quad 3")
# hist["dE_E_6_1_3"].Draw("colz")
# cut613.SetLineColor(ROOT.kRed)
# cut613.SetLineWidth(3)
# cut613.Draw("same")
#
# p1.cd(3)
# hist["dE_E_7_1_4"].SetTitle("dE-E Wire 7, Detctor 1 Quad 4")
# hist["dE_E_7_1_4"].Draw("colz")
# cut713.SetLineColor(ROOT.kRed)
# cut713.SetLineWidth(3)
# cut713.Draw("same")
#
# p1.cd(4)
# hist["dE_E_6_1_4"].SetTitle("dE-E Wire 6, Detctor 1 Quad 4")
# hist["dE_E_6_1_4"].Draw("colz")
# cut614.SetLineColor(ROOT.kRed)
# cut614.SetLineWidth(3)
# cut614.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 1

# %% [markdown]
# Detector 1
# ===

# %%
p1
# Out:
# <ROOT.TCanvas object ("Plane Detector 1") at 0x7978590>

# %%
# %%rootprint
# p1Back = rootnotes.canvas('Plane Detector 1',(696*2,472*2))
# p1Back.Divide(2,2)
#
# p1Back.cd(1)
# hist["dE_E_3_1_3"].SetTitle("dE-E Wire 3, Detctor 1 Quad 3")
# hist["dE_E_3_1_3"].Draw("colz")
# cut313.SetLineColor(ROOT.kRed)
# cut313.SetLineWidth(3)
# cut313.Draw("same")
#
# p1Back.cd(2)
# hist["dE_E_2_1_3"].SetTitle("dE-E Wire 2, Detctor 1 Quad 3")
# hist["dE_E_2_1_3"].Draw("colz")
# cut213.SetLineColor(ROOT.kRed)
# cut213.SetLineWidth(3)
# cut213.Draw("same")
#
# p1Back.cd(3)
# hist["dE_E_3_1_4"].SetTitle("dE-E Wire 3, Detctor 1 Quad 4")
# hist["dE_E_3_1_4"].Draw("colz")
# cut313.SetLineColor(ROOT.kRed)
# cut313.SetLineWidth(3)
# cut313.Draw("same")
#
# p1Back.cd(4)
# hist["dE_E_2_1_4"].SetTitle("dE-E Wire 2, Detctor 1 Quad 4")
# hist["dE_E_2_1_4"].Draw("colz")
# cut213.SetLineColor(ROOT.kRed)
# cut213.SetLineWidth(3)
# cut213.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 1

# %%
p1Back
# Out:
# <ROOT.TCanvas object ("Plane Detector 1") at 0x7f80ac0>

# %%
# %%rootprint
# p1E = rootnotes.canvas('Plane Detector 1',(696*2,472))
# p1E.Divide(2)
#
# p1E.cd(1)
# hist["e_proj_1_3_he4"].Draw()
#
# p1E.cd(2)
# hist["e_proj_1_4_he4"].Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 1

# %%
p1E
# Out:
# <ROOT.TCanvas object ("Plane Detector 1") at 0x6d8d1f0>

# %%
# %%rootprint
# p2 = rootnotes.canvas('Plane Detector 2',(696*2,472*2))
# p2.Divide(2,2)
#
# p2.cd(1).SetLogz()
# hist["dE_E_7_2_3"].SetTitle("dE-E Wire 7, Detctor 1 Quad 3")
# hist["dE_E_7_2_3"].Draw("colz")
# hist["dE_E_7_2_3"]
# cut713.SetLineColor(ROOT.kRed)
# cut713.SetLineWidth(3)
# cut713.Draw("same")
#
# p2.cd(2).SetLogz()
# hist["dE_E_6_2_3"].SetTitle("dE-E Wire 6, Detctor 2 Quad 3")
# hist["dE_E_6_2_3"].Draw("colz")
# cut613.SetLineColor(ROOT.kRed)
# cut613.SetLineWidth(3)
# cut613.Draw("same")
#
# p2.cd(3).SetLogz()
# hist["dE_E_7_2_4"].SetTitle("dE-E Wire 7, Detctor 2 Quad 4")
# hist["dE_E_7_2_4"].Draw("colz")
# cut713.SetLineColor(ROOT.kRed)
# cut713.SetLineWidth(3)
# cut713.Draw("same")
#
# p2.cd(4).SetLogz()
# hist["dE_E_6_2_4"].SetTitle("dE-E Wire 6, Detctor 2 Quad 4")
# hist["dE_E_6_2_4"].Draw("colz")
# cut614.SetLineColor(ROOT.kRed)
# cut614.SetLineWidth(3)
# cut614.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 2

# %% [markdown]
# Detector 2
# ===

# %%
p2
# Out:
# <ROOT.TCanvas object ("Plane Detector 2") at 0x6e722e0>

# %%
# %%rootprint
# p2Back = rootnotes.canvas('Plane Detector 2',(696*2,472*2))
# p2Back.Divide(2,2)
#
# p2Back.cd(1).SetLogz()
# hist["dE_E_3_2_3"].SetTitle("dE-E Wire 3, Detctor 2 Quad 3")
# hist["dE_E_3_2_3"].Draw("colz")
# cut323.SetLineColor(ROOT.kRed)
# cut323.SetLineWidth(3)
# cut323.Draw("same")
#
# p2Back.cd(2).SetLogz()
# hist["dE_E_2_2_3"].SetTitle("dE-E Wire 2, Detctor 2 Quad 3")
# hist["dE_E_2_2_3"].Draw("colz")
# cut223.SetLineColor(ROOT.kRed)
# cut223.SetLineWidth(3)
# cut223.Draw("same")
#
# p2Back.cd(3).SetLogz()
# hist["dE_E_3_2_4"].SetTitle("dE-E Wire 3, Detctor 2 Quad 4")
# hist["dE_E_3_2_4"].Draw("colz")
# cut323.SetLineColor(ROOT.kRed)
# cut323.SetLineWidth(3)
# cut323.Draw("same")
#
# p2Back.cd(4).SetLogz()
# hist["dE_E_2_2_4"].SetTitle("dE-E Wire 2, Detctor 2 Quad 4")
# hist["dE_E_2_2_4"].Draw("colz")
# cut223.SetLineColor(ROOT.kRed)
# cut223.SetLineWidth(3)
# cut223.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 2

# %%
p2Back
# Out:
# <ROOT.TCanvas object ("Plane Detector 2") at 0x6d69590>

# %%
# %%rootprint
# p2E = rootnotes.canvas('Plane Detector 2',(696*2,472))
# p2E.Divide(2)
#
# p2E.cd(1)
# hist["e_proj_2_3_he4"].Draw()
#
# p2E.cd(2)
# hist["e_proj_2_4_he4"].Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 2

# %%
p2E
# Out:
# <ROOT.TCanvas object ("Plane Detector 2") at 0x6b0b400>

# %%
# %%rootprint
# p3 = rootnotes.canvas('Plane Detector 3',(696*2,472*2))
# p3.Divide(2,2)
#
# p3.cd(1)
# hist["dE_E_7_3_3"].SetTitle("dE-E Wire 7, Detctor 3 Quad 3")
# hist["dE_E_7_3_3"].Draw("colz")
# cut733.SetLineColor(ROOT.kRed)
# cut733.SetLineWidth(3)
# cut733.Draw("same")
#
# p3.cd(2)
# hist["dE_E_6_3_3"].SetTitle("dE-E Wire 6, Detctor 3 Quad 3")
# hist["dE_E_6_3_3"].Draw("colz")
# cut633.SetLineColor(ROOT.kRed)
# cut633.SetLineWidth(3)
# cut633.Draw("same")
#
# p3.cd(3)
# hist["dE_E_7_3_4"].SetTitle("dE-E Wire 7, Detctor 3 Quad 4")
# hist["dE_E_7_3_4"].Draw("colz")
# cut733.SetLineColor(ROOT.kRed)
# cut733.SetLineWidth(3)
# cut733.Draw("same")
#
# p3.cd(4)
# hist["dE_E_6_3_4"].SetTitle("dE-E Wire 6, Detctor 3 Quad 4")
# hist["dE_E_6_3_4"].Draw("colz")
# cut634.SetLineColor(ROOT.kRed)
# cut634.SetLineWidth(3)
# cut634.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 3

# %% [markdown]
# Detector 3
# ===

# %%
p3
# Out:
# <ROOT.TCanvas object ("Plane Detector 3") at 0x6ea3300>

# %%
# %%rootprint
# p3Back = rootnotes.canvas('Plane Detector 3',(696*2,472*2))
# p3Back.Divide(2,2)
#
# p3Back.cd(1)
# hist["dE_E_3_3_3"].SetTitle("dE-E Wire 3, Detctor 3 Quad 3")
# hist["dE_E_3_3_3"].Draw("colz")
# cut333.SetLineColor(ROOT.kRed)
# cut333.SetLineWidth(3)
# cut333.Draw("same")
#
# p3Back.cd(2)
# hist["dE_E_2_3_3"].SetTitle("dE-E Wire 2, Detctor 3 Quad 3")
# hist["dE_E_2_3_3"].Draw("colz")
# cut233.SetLineColor(ROOT.kRed)
# cut233.SetLineWidth(3)
# cut233.Draw("same")
#
# p3Back.cd(3)
# hist["dE_E_3_3_4"].SetTitle("dE-E Wire 3, Detctor 3 Quad 4")
# hist["dE_E_3_3_4"].Draw("colz")
# cut333.SetLineColor(ROOT.kRed)
# cut333.SetLineWidth(3)
# cut333.Draw("same")
#
# p3Back.cd(4)
# hist["dE_E_2_3_4"].SetTitle("dE-E Wire 2, Detctor 3 Quad 4")
# hist["dE_E_2_3_4"].Draw("colz")
# cut233.SetLineColor(ROOT.kRed)
# cut233.SetLineWidth(3)
# cut233.Draw("same")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 3

# %%
p3Back
# Out:
# <ROOT.TCanvas object ("Plane Detector 3") at 0x6282db0>

# %%
# %%rootprint
# p3E = rootnotes.canvas('Plane Detector 2',(696*2,472))
# p3E.Divide(2)
#
# p3E.cd(1)
# hist["e_proj_3_3_he4"].Draw()
#
# p3E.cd(2)
# hist["e_proj_3_4_he4"].Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: Plane Detector 2

# %%
p3E
# Out:
# <ROOT.TCanvas object ("Plane Detector 2") at 0x6ebcbf0>

# %%
# %%rootprint
# e_angle = rootnotes.canvas("e_angle", (696*2,472*6))
# e_angle.Divide(2,6)
#
# e_angle.cd(1)
# hist['e_angle_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['e_angle_1_1_he4'].Draw("colz")
#
# e_angle.cd(2)
# hist['e_angle_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['e_angle_1_2_he4'].Draw("colz")
#
# e_angle.cd(3)
# hist['e_angle_1_3_he4'].SetTitle("Detctor 1 Quad 3")
# hist['e_angle_1_3_he4'].Draw("colz")
#
# e_angle.cd(4)
# hist['e_angle_1_4_he4'].SetTitle("Detctor 1 Quad 4")
# hist['e_angle_1_4_he4'].Draw("colz")
#
# e_angle.cd(5)
# hist['e_angle_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['e_angle_2_1_he4'].Draw("colz")
#
# e_angle.cd(6)
# hist['e_angle_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['e_angle_2_2_he4'].Draw("colz")
#
# e_angle.cd(7)
# hist['e_angle_2_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['e_angle_2_3_he4'].Draw("colz")
#
# e_angle.cd(8)
# hist['e_angle_2_4_he4'].SetTitle("Detctor 2 Quad 4")
# hist['e_angle_2_4_he4'].Draw("colz")
#
# e_angle.cd(9)
# hist['e_angle_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['e_angle_3_1_he4'].Draw("colz")
#
# e_angle.cd(10)
# hist['e_angle_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['e_angle_3_2_he4'].Draw("colz")
#
# e_angle.cd(11)
# hist['e_angle_3_3_he4'].SetTitle("Detctor 3 Quad 3")
# hist['e_angle_3_3_he4'].Draw("colz")
#
# e_angle.cd(12)
# hist['e_angle_3_4_he4'].SetTitle("Detctor 3 Quad 4")
# hist['e_angle_3_4_he4'].Draw("colz")

# %% [markdown]
# Resulting Energy (lab) vs. scattering angle (after fixing position in wires)
# ----

# %%
e_angle
# Out:
# <ROOT.TCanvas object ("e_angle") at 0x67c60e0>

# %%
# %%rootprint
# CM = rootnotes.canvas("CM", (696*2,472*6))
# CM.Divide(2,6)
#
# CM.cd(1)
# hist['CMe_proj_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['CMe_proj_1_1_he4'].Draw()
#
# CM.cd(2)
# hist['CMe_proj_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['CMe_proj_1_2_he4'].Draw()
#
# CM.cd(3)
# hist['CMe_proj_1_3_he4'].SetTitle("Detctor 1 Quad 3")
# hist['CMe_proj_1_3_he4'].Draw()
#
# CM.cd(4)
# hist['CMe_proj_1_4_he4'].SetTitle("Detctor 1 Quad 4")
# hist['CMe_proj_1_4_he4'].Draw()
#
# CM.cd(5)
# hist['CMe_proj_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['CMe_proj_2_1_he4'].Draw()
#
# CM.cd(6)
# hist['CMe_proj_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['CMe_proj_2_2_he4'].Draw()
#
# CM.cd(7)
# hist['CMe_proj_2_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['CMe_proj_2_3_he4'].Draw()
#
# CM.cd(8)
# hist['CMe_proj_2_4_he4'].SetTitle("Detctor 2 Quad 4")
# hist['CMe_proj_2_4_he4'].Draw()
#
# CM.cd(9)
# hist['CMe_proj_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['CMe_proj_3_1_he4'].Draw()
#
# CM.cd(10)
# hist['CMe_proj_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['CMe_proj_3_2_he4'].Draw()
#
# CM.cd(11)
# hist['CMe_proj_3_3_he4'].SetTitle("Detctor 3 Quad 3")
# hist['CMe_proj_3_3_he4'].Draw()
#
# CM.cd(12)
# hist['CMe_proj_3_4_he4'].SetTitle("Detctor 3 Quad 4")
# hist['CMe_proj_3_4_he4'].Draw()
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: CM

# %% [markdown]
# CM Energy spectra
# ---

# %%
CM
# Out:
# <ROOT.TCanvas object ("CM") at 0x7f311a0>

# %% [markdown]
# Conclusion
# ===
#
# * Wire positions look good.
# * Resolution seems decent (Looks like we can discern the space between detector active areas)
#
# To do
# ===
#
# * Need to understand all parts of the Energy (lab) specta; adjust cuts if needed.
# * Maybe position cuts can be imposed to clean up spectra?
# * Vlad suggested I plot position of 6He in the wires (working on this now)
