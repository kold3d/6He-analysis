# %% [markdown]
# <sup>6</sup>He(α,α) Analysis Update
# =====================
# May 19, 2017
# --------------------

# %% [markdown]
# * Last week, we saw that wire 6->2 did not have good seperation
#     * Looked at dE sum to see if it has better seperation. No luck
# * Looked at the events I select for in the back wires as alphas in the front wires (with Vlad).
#     * Nothing to show here for that yet, but it looks interesting, and may help us better determine where these particles are coming from
# * Reconstructed angle, vertex, etc. using the front and back wire positions (now that they are fixed, and reasonalbe)
#     * Things are not as clean as we hoped. I'll show these plots today.

# %%
import ROOT
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F, TH2F
import rootprint
import rootnotes
import utils

# %%
out = TFile("~/Desktop/gr-gmaster_home/analysis/analysis/out.root")

# %%
# %%rootprint
# hist = {}
# for h in out.GetListOfKeys():
#     h = h.ReadObj()
#     hist[h.GetName()] = h

# %% [markdown]
# Energy vs. Angle
# ===

# %%
# %%rootprint
# e_angle_det1 = rootnotes.canvas("e_angle_det1", (696*2,472*2))
# e_angle_det1.Divide(2,2)
#
# e_angle_det1.cd(1)
# hist['e_angle_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['e_angle_1_1_he4'].Draw("colz")
#
# e_angle_det1.cd(2)
# hist['e_angle_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['e_angle_1_2_he4'].Draw("colz")
#
# e_angle_det1.cd(3)
# hist['e_angle_1_3_he4'].SetTitle("Detctor 1 Quad 3")
# hist['e_angle_1_3_he4'].Draw("colz")
#
# e_angle_det1.cd(4)
# hist['e_angle_1_4_he4'].SetTitle("Detctor 1 Quad 4")
# hist['e_angle_1_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: e_angle_det1

# %%
e_angle_det1
# Out:
# <ROOT.TCanvas object ("e_angle_det1") at 0x8ce5b10>

# %%
# %%rootprint
# e_angle_det2 = rootnotes.canvas("e_angle_det2", (696*2,472*2))
# e_angle_det2.Divide(2,2)
#
# e_angle_det2.cd(1)
# hist['e_angle_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['e_angle_2_1_he4'].Draw("colz")
#
# e_angle_det2.cd(2)
# hist['e_angle_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['e_angle_2_2_he4'].Draw("colz")
#
# e_angle_det2.cd(3)
# hist['e_angle_2_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['e_angle_2_3_he4'].Draw("colz")
#
# e_angle_det2.cd(4)
# hist['e_angle_2_4_he4'].SetTitle("Detctor 2 Quad 4")
# hist['e_angle_2_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: e_angle_det2

# %%
e_angle_det2
# Out:
# <ROOT.TCanvas object ("e_angle_det2") at 0x8d445b0>

# %%
# %%rootprint
# e_angle_det3 = rootnotes.canvas("e_angle_det3", (696*2,472*2))
# e_angle_det3.Divide(2,2)
#
# e_angle_det3.cd(1)
# hist['e_angle_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['e_angle_3_1_he4'].Draw("colz")
#
# e_angle_det3.cd(2)
# hist['e_angle_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['e_angle_3_2_he4'].Draw("colz")
#
# e_angle_det3.cd(3)
# hist['e_angle_3_3_he4'].SetTitle("Detctor 3 Quad 3")
# hist['e_angle_3_3_he4'].Draw("colz")
#
# e_angle_det3.cd(4)
# hist['e_angle_3_4_he4'].SetTitle("Detctor 3 Quad 4")
# hist['e_angle_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: e_angle_det3

# %%
e_angle_det3
# Out:
# <ROOT.TCanvas object ("e_angle_det3") at 0x6d5d150>

# %% [markdown]
# Energy vs. Vertex
# ===

# %%
# %%rootprint
# E_vertex_det1 = rootnotes.canvas("E_vertex_det1", (696*2,472*2))
# E_vertex_det1.Divide(2,2)
#
# E_vertex_det1.cd(1)
# hist['e_vertex_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['e_vertex_1_1_he4'].Draw("colz")
#
# E_vertex_det1.cd(2)
# hist['e_vertex_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['e_vertex_1_2_he4'].Draw("colz")
#
# E_vertex_det1.cd(3)
# hist['e_vertex_1_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['e_vertex_1_3_he4'].Draw("colz")
#
# E_vertex_det1.cd(4)
# hist['e_vertex_1_4_he4'].SetTitle("Detctor 1 Quad 4")
# hist['e_vertex_1_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: E_vertex_det1

# %%
E_vertex_det1
# Out:
# <ROOT.TCanvas object ("E_vertex_det1") at 0x8d74360>

# %% [markdown]
# * Events that are reconstructed to have come from beyond the entrance window have been set to the entrance window
# * Events reconstructed to be beyond the detector are interesting and I probed further. This merits a discussion with the next set of plots

# %%
# %%rootprint
# E_vertex_det2 = rootnotes.canvas("E_vertex_det2", (696*2,472*2))
# E_vertex_det2.Divide(2,2)
#
# E_vertex_det2.cd(1)
# hist['e_vertex_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['e_vertex_2_1_he4'].Draw("colz")
#
# E_vertex_det2.cd(2)
# hist['e_vertex_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['e_vertex_2_2_he4'].Draw("colz")
#
# E_vertex_det2.cd(3)
# hist['e_vertex_2_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['e_vertex_2_3_he4'].Draw("colz")
#
# E_vertex_det2.cd(4)
# hist['e_vertex_2_4_he4'].SetTitle("Detctor 2 Quad 4")
# hist['e_vertex_2_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: E_vertex_det2

# %%
E_vertex_det2
# Out:
# <ROOT.TCanvas object ("E_vertex_det2") at 0x8d80de0>

# %%
# %%rootprint
# E_vertex_det3 = rootnotes.canvas("E_vertex_det3", (696*2,472*2))
# E_vertex_det3.Divide(2,2)
#
# E_vertex_det3.cd(1)
# hist['e_vertex_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['e_vertex_3_1_he4'].Draw("colz")
#
# E_vertex_det3.cd(2)
# hist['e_vertex_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['e_vertex_3_2_he4'].Draw("colz")
#
# E_vertex_det3.cd(3)
# hist['e_vertex_3_3_he4'].SetTitle("Detctor 3 Quad 3")
# hist['e_vertex_3_3_he4'].Draw("colz")
#
# E_vertex_det3.cd(4)
# hist['e_vertex_3_4_he4'].SetTitle("Detctor 3 Quad 4")
# hist['e_vertex_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: E_vertex_det3

# %%
E_vertex_det3
# Out:
# <ROOT.TCanvas object ("E_vertex_det3") at 0x8d66720>

# %% [markdown]
# Vertex vs. Angle
# ===
#
# * In the past, I've only looked at abs(angle) and vertex >= 500

# %%
# %%rootprint
# vertex_angle_det1 = rootnotes.canvas("vertex_angle_det1", (696*2,472*2))
# vertex_angle_det1.Divide(2,2)
#
# vertex_angle_det1.cd(1)
# hist['vertex_angle_1_1_he4'].SetTitle("Detctor 1 Quad 1")
# hist['vertex_angle_1_1_he4'].Draw("colz")
#
# vertex_angle_det1.cd(2)
# hist['vertex_angle_1_2_he4'].SetTitle("Detctor 1 Quad 2")
# hist['vertex_angle_1_2_he4'].Draw("colz")
#
# vertex_angle_det1.cd(3)
# hist['vertex_angle_1_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['vertex_angle_1_3_he4'].Draw("colz")
#
# vertex_angle_det1.cd(4)
# hist['vertex_angle_1_4_he4'].SetTitle("Detctor 1 Quad 4")
# hist['vertex_angle_1_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: vertex_angle_det1

# %%
vertex_angle_det1
# Out:
# <ROOT.TCanvas object ("vertex_angle_det1") at 0x8dbf940>

# %%
# %%rootprint
# vertex_angle_det2 = rootnotes.canvas("vertex_angle_det2", (696*2,472*2))
# vertex_angle_det2.Divide(2,2)
#
# vertex_angle_det2.cd(1)
# hist['vertex_angle_2_1_he4'].SetTitle("Detctor 2 Quad 1")
# hist['vertex_angle_2_1_he4'].Draw("colz")
# hist['vertex_angle_2_1_he4'].SetStats(0)
#
# vertex_angle_det2.cd(2)
# hist['vertex_angle_2_2_he4'].SetTitle("Detctor 2 Quad 2")
# hist['vertex_angle_2_2_he4'].Draw("colz")
# hist['vertex_angle_2_2_he4'].SetStats(0)
#
# vertex_angle_det2.cd(3)
# hist['vertex_angle_2_3_he4'].SetTitle("Detctor 2 Quad 3")
# hist['vertex_angle_2_3_he4'].Draw("colz")
# hist['vertex_angle_2_3_he4'].SetStats(0)
#
# vertex_angle_det2.cd(4)
# hist['vertex_angle_2_4_he4'].SetTitle("Detctor 2 Quad 4")
# hist['vertex_angle_2_4_he4'].Draw("colz")
# hist['vertex_angle_2_4_he4'].SetStats(0)
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: vertex_angle_det2

# %%
vertex_angle_det2
# Out:
# <ROOT.TCanvas object ("vertex_angle_det2") at 0x8d92a80>

# %%
# %%rootprint
# vertex_angle_det3 = rootnotes.canvas("vertex_angle_det3", (696*2,472*2))
# vertex_angle_det3.Divide(2,2)
#
# vertex_angle_det3.cd(1)
# hist['vertex_angle_3_1_he4'].SetTitle("Detctor 3 Quad 1")
# hist['vertex_angle_3_1_he4'].Draw("colz")
# hist['vertex_angle_3_1_he4'].SetStats(0)
#
# vertex_angle_det3.cd(2)
# hist['vertex_angle_3_2_he4'].SetTitle("Detctor 3 Quad 2")
# hist['vertex_angle_3_2_he4'].Draw("colz")
# hist['vertex_angle_3_2_he4'].SetStats(0)
#
# vertex_angle_det3.cd(3)
# hist['vertex_angle_3_3_he4'].SetTitle("Detctor 3 Quad 3")
# hist['vertex_angle_3_3_he4'].Draw("colz")
# hist['vertex_angle_3_3_he4'].SetStats(0)
#
# vertex_angle_det3.cd(4)
# hist['vertex_angle_3_4_he4'].SetTitle("Detctor 3 Quad 4")
# hist['vertex_angle_3_4_he4'].Draw("colz")
# hist['vertex_angle_3_4_he4'].SetStats(0)
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: vertex_angle_det3

# %%
vertex_angle_det3
# Out:
# <ROOT.TCanvas object ("vertex_angle_det3") at 0x8ddbd70>

# %% [markdown]
# Vertex vs. Wire Position
# ===

# %%
# %%rootprint
# wire6 = rootnotes.canvas("wire6Pos", (696*2,472*3))
# wire6.Divide(2,3)
#
# wire6.cd(1)
# hist['vertex_wirePos_6_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire6 Pos")
# hist['vertex_wirePos_6_1_3_he4'].Draw("colz")
# hist['vertex_wirePos_6_1_3_he4'].SetStats(1)
#
# wire6.cd(2)
# hist['vertex_wirePos_6_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire6 Pos")
# hist['vertex_wirePos_6_1_4_he4'].Draw("colz")
#
# wire6.cd(3)
# hist['vertex_wirePos_6_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire6 Pos")
# hist['vertex_wirePos_6_2_3_he4'].Draw("colz")
#
# wire6.cd(4)
# hist['vertex_wirePos_6_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire6 Pos")
# hist['vertex_wirePos_6_2_4_he4'].Draw("colz")
#
# wire6.cd(5)
# hist['vertex_wirePos_6_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire6 Pos")
# hist['vertex_wirePos_6_3_3_he4'].Draw("colz")
#
# wire6.cd(6)
# hist['vertex_wirePos_6_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire6 Pos")
# hist['vertex_wirePos_6_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire6Pos

# %%
wire6
# Out:
# <ROOT.TCanvas object ("wire6Pos") at 0x8d7ef60>

# %%
# %%rootprint
# wire7 = rootnotes.canvas("wire7Pos", (696*2,472*6))
# wire7.Divide(2,6)
#
# wire7.cd(1)
# hist['vertex_wirePos_7_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire7 Pos")
# hist['vertex_wirePos_7_1_1_he4'].Draw("colz")
#
# wire7.cd(2)
# hist['vertex_wirePos_7_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire7 Pos")
# hist['vertex_wirePos_7_1_2_he4'].Draw("colz")
#
# wire7.cd(3)
# hist['vertex_wirePos_7_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire7 Pos")
# hist['vertex_wirePos_7_1_3_he4'].Draw("colz")
#
# wire7.cd(4)
# hist['vertex_wirePos_7_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire7 Pos")
# hist['vertex_wirePos_7_1_4_he4'].Draw("colz")
#
# wire7.cd(5)
# hist['vertex_wirePos_7_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire7 Pos")
# hist['vertex_wirePos_7_2_1_he4'].Draw("colz")
#
# wire7.cd(6)
# hist['vertex_wirePos_7_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire7 Pos")
# hist['vertex_wirePos_7_2_2_he4'].Draw("colz")
#
# wire7.cd(7)
# hist['vertex_wirePos_7_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire7 Pos")
# hist['vertex_wirePos_7_2_3_he4'].Draw("colz")
#
# wire7.cd(8)
# hist['vertex_wirePos_7_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire7 Pos")
# hist['vertex_wirePos_7_2_4_he4'].Draw("colz")
#
# wire7.cd(9)
# hist['vertex_wirePos_7_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire7 Pos")
# hist['vertex_wirePos_7_3_1_he4'].Draw("colz")
#
# wire7.cd(10)
# hist['vertex_wirePos_7_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire7 Pos")
# hist['vertex_wirePos_7_3_2_he4'].Draw("colz")
#
# wire7.cd(11)
# hist['vertex_wirePos_7_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire7 Pos")
# hist['vertex_wirePos_7_3_3_he4'].Draw("colz")
#
# wire7.cd(12)
# hist['vertex_wirePos_7_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire7 Pos")
# hist['vertex_wirePos_7_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire7Pos

# %%
wire7
# Out:
# <ROOT.TCanvas object ("wire7Pos") at 0x70b9d70>

# %%
# %%rootprint
# wire8 = rootnotes.canvas("wire8Pos", (696*2,472*3))
# wire8.Divide(2,3)
#
# wire8.cd(1)
# hist['vertex_wirePos_8_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire8 Pos")
# hist['vertex_wirePos_8_1_1_he4'].Draw("colz")
#
# wire8.cd(2)
# hist['vertex_wirePos_8_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire8 Pos")
# hist['vertex_wirePos_8_1_2_he4'].Draw("colz")
#
# wire8.cd(3)
# hist['vertex_wirePos_8_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire8 Pos")
# hist['vertex_wirePos_8_2_1_he4'].Draw("colz")
#
# wire8.cd(4)
# hist['vertex_wirePos_8_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire8 Pos")
# hist['vertex_wirePos_8_2_2_he4'].Draw("colz")
#
# wire8.cd(5)
# hist['vertex_wirePos_8_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire8 Pos")
# hist['vertex_wirePos_8_3_1_he4'].Draw("colz")
#
# wire8.cd(6)
# hist['vertex_wirePos_8_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire8 Pos")
# hist['vertex_wirePos_8_3_2_he4'].Draw("colz")

# %%
wire8
# Out:
# <ROOT.TCanvas object ("wire8Pos") at 0x7d06750>

# %%
# %%rootprint
# wire2 = rootnotes.canvas("wire7Pos", (696*2,472*3))
# wire2.Divide(2,3)
#
# wire2.cd(1)
# hist['vertex_wirePos_2_1_3_he4'].SetTitle("Detector 1 Quad 3 Wire2 Pos")
# hist['vertex_wirePos_2_1_3_he4'].Draw("colz")
#
# wire2.cd(2)
# hist['vertex_wirePos_2_1_4_he4'].SetTitle("Detector 1 Quad 4 Wire2 Pos")
# hist['vertex_wirePos_2_1_4_he4'].Draw("colz")
#
# wire2.cd(3)
# hist['vertex_wirePos_2_2_3_he4'].SetTitle("Detector 2 Quad 3 Wire2 Pos")
# hist['vertex_wirePos_2_2_3_he4'].Draw("colz")
#
# wire2.cd(4)
# hist['vertex_wirePos_2_2_4_he4'].SetTitle("Detector 2 Quad 4 Wire2 Pos")
# hist['vertex_wirePos_2_2_4_he4'].Draw("colz")
#
# wire2.cd(5)
# hist['vertex_wirePos_2_3_3_he4'].SetTitle("Detector 3 Quad 3 Wire2 Pos")
# hist['vertex_wirePos_2_3_3_he4'].Draw("colz")
#
# wire2.cd(6)
# hist['vertex_wirePos_2_3_4_he4'].SetTitle("Detector 3 Quad 4 Wire2 Pos")
# hist['vertex_wirePos_2_3_4_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire7Pos

# %%
wire2
# Out:
# <ROOT.TCanvas object ("wire7Pos") at 0x7cbf920>

# %%
# %%rootprint
# wire3 = rootnotes.canvas("wire3Pos", (696*2,472*3))
# wire3.Divide(2,3)
#
# wire3.cd(1)
# hist['vertex_wirePos_3_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire3 Pos")
# hist['vertex_wirePos_3_1_1_he4'].Draw("colz")
#
# wire3.cd(2)
# hist['vertex_wirePos_3_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire3 Pos")
# hist['vertex_wirePos_3_1_2_he4'].Draw("colz")
#
# wire3.cd(3)
# hist['vertex_wirePos_3_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire3 Pos")
# hist['vertex_wirePos_3_2_1_he4'].Draw("colz")
#
# wire3.cd(4)
# hist['vertex_wirePos_3_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire3 Pos")
# hist['vertex_wirePos_3_2_2_he4'].Draw("colz")
#
# wire3.cd(5)
# hist['vertex_wirePos_3_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire3 Pos")
# hist['vertex_wirePos_3_3_1_he4'].Draw("colz")
#
# wire3.cd(6)
# hist['vertex_wirePos_3_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire3 Pos")
# hist['vertex_wirePos_3_3_2_he4'].Draw("colz")

# %%
wire3
# Out:
# <ROOT.TCanvas object ("wire3Pos") at 0x69c2930>

# %%
# %%rootprint
# wire4 = rootnotes.canvas("wire4Pos", (696*2,472*3))
# wire4.Divide(2,3)
#
# wire4.cd(1)
# hist['vertex_wirePos_4_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire4 Pos")
# hist['vertex_wirePos_4_1_1_he4'].Draw("colz")
#
# wire4.cd(2)
# hist['vertex_wirePos_4_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire4 Pos")
# hist['vertex_wirePos_4_1_2_he4'].Draw("colz")
#
# wire4.cd(3)
# hist['vertex_wirePos_4_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire4 Pos")
# hist['vertex_wirePos_4_2_1_he4'].Draw("colz")
#
# wire4.cd(4)
# hist['vertex_wirePos_4_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire4 Pos")
# hist['vertex_wirePos_4_2_2_he4'].Draw("colz")
#
# wire4.cd(5)
# hist['vertex_wirePos_4_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire4 Pos")
# hist['vertex_wirePos_4_3_1_he4'].Draw("colz")
#
# wire4.cd(6)
# hist['vertex_wirePos_4_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire4 Pos")
# hist['vertex_wirePos_4_3_2_he4'].Draw("colz")

# %%
wire4
# Out:
# <ROOT.TCanvas object ("wire4Pos") at 0x69c4f40>

# %%
# %%rootprint
# wire5 = rootnotes.canvas("wire4Pos", (696*2,472*3))
# wire5.Divide(2,3)
#
# wire5.cd(1)
# hist['vertex_wirePos_5_1_1_he4'].SetTitle("Detector 1 Quad 1 Wire5 Pos")
# hist['vertex_wirePos_5_1_1_he4'].Draw("colz")
#
# wire5.cd(2)
# hist['vertex_wirePos_5_1_2_he4'].SetTitle("Detector 1 Quad 2 Wire5 Pos")
# hist['vertex_wirePos_5_1_2_he4'].Draw("colz")
#
# wire5.cd(3)
# hist['vertex_wirePos_5_2_1_he4'].SetTitle("Detector 2 Quad 1 Wire5 Pos")
# hist['vertex_wirePos_5_2_1_he4'].Draw("colz")
#
# wire5.cd(4)
# hist['vertex_wirePos_5_2_2_he4'].SetTitle("Detector 2 Quad 2 Wire5 Pos")
# hist['vertex_wirePos_5_2_2_he4'].Draw("colz")
#
# wire5.cd(5)
# hist['vertex_wirePos_5_3_1_he4'].SetTitle("Detector 3 Quad 1 Wire5 Pos")
# hist['vertex_wirePos_5_3_1_he4'].Draw("colz")
#
# wire5.cd(6)
# hist['vertex_wirePos_5_3_2_he4'].SetTitle("Detector 3 Quad 2 Wire5 Pos")
# hist['vertex_wirePos_5_3_2_he4'].Draw("colz")
# Out:
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: wire4Pos

# %%
wire5
# Out:
# <ROOT.TCanvas object ("wire4Pos") at 0x69c35f0>

# %% [markdown]
# Conclusion + to do:
# ---
#
# * Reason for having some events with poor reconstruction is possibly because of the position resolution in the wires.
#     * If abs(backPosition) < abs(frontPosition), reconstruction will fail here.
# * Working with vlad to determine the origin of all the alphas. Vlad suspects scattering of lollipop edge may contribute.
